# %%
using ApproxFun, OrdinaryDiffEq, Sundials, BenchmarkTools
using Plots; gr()

S = Fourier()
n = 1000 # n = 1000 takes forever
T = ApproxFun.plan_transform(S, n)
Ti = ApproxFun.plan_itransform(S, n)
x = points(S, n)


u₀ = T*cos.(cos.(x-0.1))
D2 = Derivative(S,2)
L = D2[1:n,1:n]

# Simple Heat

function heat(du,u,L,t)
    A_mul_B!(du, L, u)
end
prob = ODEProblem(heat, u₀, (0.0,10.0),L)
@time u = solve(prob, CVODE_BDF(linear_solver=:Diagonal); reltol=1e-8,abstol=1e-8)
plot(x,Ti*u(0.0))
plot!(x,Ti*u(0.5))
plot!(x,Ti*u(2.0))
plot!(x,Ti*u(10.0))
# Out:
#   0.011343 seconds (6.05 k allocations: 3.610 MiB)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip5400">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5401">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip5400)" points="
# 32.4745,375.869 580.315,375.869 580.315,11.811 32.4745,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip5402">
#     <rect x="32" y="11" width="549" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,375.869 32.4745,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   119.753,375.869 119.753,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   207.032,375.869 207.032,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   294.311,375.869 294.311,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   381.59,375.869 381.59,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   468.868,375.869 468.868,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   556.147,375.869 556.147,11.811
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,328.591 580.315,328.591
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,249.396 580.315,249.396
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,170.201 580.315,170.201
#   "/>
# <polyline clip-path="url(#clip5402)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   32.4745,91.006 580.315,91.006
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 32.4745,11.811
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,375.869 32.4745,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   119.753,375.869 119.753,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   207.032,375.869 207.032,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   294.311,375.869 294.311,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   381.59,375.869 381.59,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   468.868,375.869 468.868,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   556.147,375.869 556.147,370.408
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,328.591 40.6921,328.591
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,249.396 40.6921,249.396
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,170.201 40.6921,170.201
#   "/>
# <polyline clip-path="url(#clip5400)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,91.006 40.6921,91.006
#   "/>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 32.4745, 389.669)" x="32.4745" y="389.669">0</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 119.753, 389.669)" x="119.753" y="389.669">1</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 207.032, 389.669)" x="207.032" y="389.669">2</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 294.311, 389.669)" x="294.311" y="389.669">3</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 381.59, 389.669)" x="381.59" y="389.669">4</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 468.868, 389.669)" x="468.868" y="389.669">5</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 556.147, 389.669)" x="556.147" y="389.669">6</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 333.091)" x="26.4745" y="333.091">0.6</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 253.896)" x="26.4745" y="253.896">0.7</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 174.701)" x="26.4745" y="174.701">0.8</text>
# </g>
# <g clip-path="url(#clip5400)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 26.4745, 95.506)" x="26.4745" y="95.506">0.9</text>
# </g>
# <polyline clip-path="url(#clip5402)" style="stroke:#009af9; stroke-width:1; stroke-opacity:1; fill:none" points="
#   32.4745,372.545 33.0229,372.949 33.5713,373.326 34.1197,373.678 34.668,374.004 35.2164,374.303 35.7648,374.577 36.3132,374.824 36.8616,375.045 37.41,375.24
#   37.9584,375.409 38.5068,375.551 39.0552,375.667 39.6035,375.757 40.1519,375.821 40.7003,375.858 41.2487,375.869 41.7971,375.853 42.3455,375.812 42.8939,375.744
#   43.4423,375.649 43.9907,375.529 44.539,375.382 45.0874,375.209 45.6358,375.01 46.1842,374.784 46.7326,374.532 47.281,374.254 47.8294,373.95 48.3778,373.62
#   48.9262,373.264 49.4745,372.882 50.0229,372.474 50.5713,372.04 51.1197,371.58 51.6681,371.095 52.2165,370.583 52.7649,370.046 53.3133,369.483 53.8617,368.895
#   54.41,368.281 54.9584,367.642 55.5068,366.977 56.0552,366.287 56.6036,365.572 57.152,364.832 57.70

# %%
?airyai
# Out:
# search: airyai airyaix airyaiprime airyaiprimex
# ```
# airyai(x)
# ```
#
# Airy function of the first kind $\operatorname{Ai}(x)$.

# %%
x=Fun()
u0=0.0x

N=u->[u(-1)-1,u(1)+0.5,0.001u''+6*(1-x^2)*u'+u^2-1]
@time u=newton(N,u0)
plot(u)
# Out:
#   1.509067 seconds (16.25 M allocations: 543.108 MiB, 4.04% gc time)
# <?xml version="1.0" encoding="utf-8"?>
# <svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" width="600" height="400" viewBox="0 0 600 400">
# <defs>
#   <clipPath id="clip6200">
#     <rect x="0" y="0" width="600" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6200)" points="
# 0,400 600,400 600,0 0,0
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6201">
#     <rect x="120" y="0" width="421" height="400"/>
#   </clipPath>
# </defs>
# <polygon clip-path="url(#clip6200)" points="
# 46.1926,375.869 580.315,375.869 580.315,11.811 46.1926,11.811
#   " fill="#ffffff" fill-opacity="1"/>
# <defs>
#   <clipPath id="clip6202">
#     <rect x="46" y="11" width="535" height="365"/>
#   </clipPath>
# </defs>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   112.958,375.869 112.958,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   179.723,375.869 179.723,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   246.488,375.869 246.488,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   313.254,375.869 313.254,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   380.019,375.869 380.019,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   446.784,375.869 446.784,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   513.55,375.869 513.55,11.811
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.1926,350.088 580.315,350.088
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.1926,301.76 580.315,301.76
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.1926,253.433 580.315,253.433
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.1926,205.106 580.315,205.106
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.1926,156.779 580.315,156.779
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.1926,108.452 580.315,108.452
#   "/>
# <polyline clip-path="url(#clip6202)" style="stroke:#000000; stroke-width:0.5; stroke-opacity:0.1; fill:none" points="
#   46.1926,60.1245 580.315,60.1245
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,375.869 580.315,375.869
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,375.869 46.1926,11.811
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   112.958,375.869 112.958,370.408
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   179.723,375.869 179.723,370.408
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   246.488,375.869 246.488,370.408
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   313.254,375.869 313.254,370.408
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   380.019,375.869 380.019,370.408
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   446.784,375.869 446.784,370.408
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   513.55,375.869 513.55,370.408
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,350.088 54.2044,350.088
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,301.76 54.2044,301.76
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,253.433 54.2044,253.433
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,205.106 54.2044,205.106
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,156.779 54.2044,156.779
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,108.452 54.2044,108.452
#   "/>
# <polyline clip-path="url(#clip6200)" style="stroke:#000000; stroke-width:1; stroke-opacity:1; fill:none" points="
#   46.1926,60.1245 54.2044,60.1245
#   "/>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 112.958, 389.669)" x="112.958" y="389.669">-0.75</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 179.723, 389.669)" x="179.723" y="389.669">-0.50</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 246.488, 389.669)" x="246.488" y="389.669">-0.25</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 313.254, 389.669)" x="313.254" y="389.669">0.00</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 380.019, 389.669)" x="380.019" y="389.669">0.25</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 446.784, 389.669)" x="446.784" y="389.669">0.50</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:middle;" transform="rotate(0, 513.55, 389.669)" x="513.55" y="389.669">0.75</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 40.1926, 354.588)" x="40.1926" y="354.588">-0.75</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 40.1926, 306.26)" x="40.1926" y="306.26">-0.50</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-serif; font-size:12; text-anchor:end;" transform="rotate(0, 40.1926, 257.933)" x="40.1926" y="257.933">-0.25</text>
# </g>
# <g clip-path="url(#clip6200)">
# <text style="fill:#000000; fill-opacity:1; font-family:Arial,Helvetica Neue,Helvetica,sans-se

# %%
f = Fun(Taylor(),[1,2,3])
# Out:
# Fun(Taylor(🕒),[1, 2, 3])

# %%
Fun(exp)(1)
# Out:
# 2.718281828459044

# %%
Space(Interval())
# Out:
# Chebyshev(【-1.0,1.0】)

# %%
t = Fun(0..1)
# Out:
# Fun(Chebyshev(【0.0,1.0】),[0.5, 0.5])

# %%
t(0.5)
# Out:
# 0.5

# %%
t = Fun(0..1);

@time u = [Evaluation(0); 𝒟 - t]  \ [1;0];
# Out:
#   0.000811 seconds (1.59 k allocations: 75.969 KiB)

# %%
d = (-1..1)^2
x,y = Fun(d)
f = exp.(-10(x+0.3)^2-20(y-0.2)^2)  # use broadcasting as exp(f) not implemented in 2D
A = [Dirichlet(d);Δ]              # Δ is an alias for Laplacian()
@time u = A \ [zeros(∂(d));f]     #4s for ~3k coefficients
# Out:
# MethodError: no method matching *(::IntervalSets.ClosedInterval{Int64}, ::IntervalSets.ClosedInterval{Int64})
# Closest candidates are:
#   *(::Any, ::Any, ::Any, ::Any...) at operators.jl:424
#   *(::IntervalSets.ClosedInterval, ::ApproxFun.Domain) at C:\Users\Max\AppData\Local\JuliaPro-0.6.2.1\pkgs-0.6.2.1\v0.6\ApproxFun\src\Domains/Domains.jl:90
#   *(::ApproxFun.Domain, ::IntervalSets.ClosedInterval) at C:\Users\Max\AppData\Local\JuliaPro-0.6.2.1\pkgs-0.6.2.1\v0.6\ApproxFun\src\Domains/Domains.jl:91
#   ...
#
# Stacktrace:
#  [1] power_by_squaring(::IntervalSets.ClosedInterval{Int64}, ::Int64) at .\intfuncs.jl:169
#  [2] literal_pow(::Base.#^, ::IntervalSets.ClosedInterval{Int64}, ::Type{Val{2}}) at .\intfuncs.jl:208
#  [3] include_string(::String, ::String) at .\loading.jl:522

# %%
x = Fun()
N = u->[u(-1.)-c;u(1.);ε*u''+6*(1-x^2)*u'+u^2-1.]
u = newton(N,u0)
# Out:
# UndefVarError: c not defined
#
# Stacktrace:
#  [1] (::##43#44)(::ApproxFun.DualFun{ApproxFun.Fun{ApproxFun.Chebyshev{ApproxFun.Segment{Float64},Float64},Float64,Array{Float64,1}},ApproxFun.ConstantOperator{Float64,ApproxFun.Chebyshev{ApproxFun.Segment{Float64},Float64}}}) at .\In[52]:2
#  [2] #newton#736(::Int64, ::Float64, ::Function, ::##43#44, ::ApproxFun.Fun{ApproxFun.Chebyshev{ApproxFun.Segment{Float64},Float64},Float64,Array{Float64,1}}) at C:\Users\Max\AppData\Local\JuliaPro-0.6.2.1\pkgs-0.6.2.1\v0.6\ApproxFun\src\Extras\autodifferentiation.jl:90
#  [3] newton(::Function, ::ApproxFun.Fun{ApproxFun.Chebyshev{ApproxFun.Segment{Float64},Float64},Float64,Array{Float64,1}}) at C:\Users\Max\AppData\Local\JuliaPro-0.6.2.1\pkgs-0.6.2.1\v0.6\ApproxFun\src\Extras\autodifferentiation.jl:87
#  [4] include_string(::String, ::String) at .\loading.jl:522
