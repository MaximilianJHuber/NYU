# %% [markdown]
# In this exercise I solve a deterministic growth model using simulated data generated from an economy with parameters $\beta = 0.95$, $\alpha = 0.3$, $A = 1.0$, $\delta = 0.05$, $\gamma = 2.0$. I initiate the variables of the mathematical program at the true values, which should make the optimization easy.

# %%
using CSV
using Plots; pyplot()

df = CSV.read("data.csv"; header=false, types=[Float64, Float64])
dataK = convert(Vector{Float64}, df[1])
dataC = convert(Vector{Float64}, df[2])

plot(dataK, label="capital")
plot!(dataC, label="consumption")
# Out:
# WARNING: Method definition ==(Base.Nullable{S}, Base.Nullable{T}) in module Base at nullable.jl:238 overwritten in module NullableArrays at /home/juser/.julia/v0.6/NullableArrays/src/operators.jl:99.
# WARNING: Compat.AsyncCondition is deprecated, use Base.AsyncCondition instead.
#   likely near In[1]:2
# WARNING: Compat.AsyncCondition is deprecated, use Base.AsyncCondition instead.
#   likely near In[1]:2
# <img src="data:image/png;base64,..." />

# %% [markdown]
# The economy's steady state for capital is:

# %%
k_stst = 4.628988089138438;

# %% [markdown]
# # The Mathematical Program
# I define the needed function related to utility and production:

# %%
u_crra_prime(c, γ) = begin
    if (c <= 0)
        return -1000000.
        else
        return c^-γ
    end
end

u_crra_prime_inv(u, γ) = begin
    if (u <= 0)
        return -1000000.
    else
        return u^(-1/γ) 
    end
end

function f(k, α, A)
    if (k <= 0)
        return zero(k)
    else
        A*k^α
    end
end

function f_prime(k, α, A)
    if (k <= 0)
        return zero(k)
    else
        A*α*k^(α-1)
    end
end
# Out:
# f_prime (generic function with 1 method)

# %% [markdown]
# I use the Julia Mathematical Programming languange JuMP and the IpOpt solver:

# %%
using JuMP
using Ipopt

m = Model(solver=IpoptSolver(print_level=5, max_iter=600));

# %% [markdown]
# I define the deep parameters variables and give the the correct starting values:

# %%
@variable(m, 0 <= β <= 1, start = 0.90)
@variable(m, 0 <= δ <= 1, start = 0.15)
@variable(m, 0 <= α <= 1, start = 0.3)
@variable(m, A >= 0, start = 1)
@variable(m, γ >= 0, start = 2);

# %% [markdown]
# The policy function is approximated by 10 Chebyshev polynomials on a grid around the steady state for capital, the coefficients on the polynomials are $\theta$:

# %%
@variable(m, θ[1:10], start = 0);

# %% [markdown]
# I define a grid on capital, $K$, with 10 nodes, and evaluate the Chebyshev polynomials at those point into $\Psi$ and at the observed data points into $\Phi$:

# %%
using BasisMatrices
basis = Basis(ChebParams(10, 0.2*k_stst, 2*k_stst))
K = nodes(basis)[1] #grid
Ψ = BasisMatrix(basis, Expanded(), K).vals[1]
Φ = BasisMatrix(basis, Expanded(), dataK).vals[1];

# %% [markdown]
# And I initialize $\theta$ such that the consumer myopically consumes almost everything available, leaving just $0.5$ capital for the next period:

# %%
initial_θ = Ψ \ (f.(K, getvalue(α), getvalue(A)) + (1-getvalue(δ))*K - 0.5)

for i in 1:10
    setvalue(θ[i], initial_θ[i])
end

# %% [markdown]
# In the equilibrium constraint the polynomials have to be evaluated also outside the grid, I define this function here:

# %%
function Ψprime(x, order)
    k_stst = 4.628988089138438
    a = 0.2*k_stst
    b = 2*k_stst
        
    z = (2/(b-a)) * (x-(a+b)/2)
    
    if (order == 1)
        return 1.
    elseif (order == 2)
        return z
    else
        
        out1 = 1.
        out2 = z
        out3 = 0.

        for j in 3:order
            out3 = 2. * z * out2 - out1
            out1 = out2
            out2 = out3
        end

        return out3
    end
end
# Out:
# Ψprime (generic function with 1 method)

# %% [markdown]
# I register all user-defined functions with JuMP for automatic differentiation:

# %%
JuMP.register(m, :Ψprime, 2, Ψprime, autodiff=true)
JuMP.register(m, :u_crra_prime, 2, u_crra_prime, autodiff=true)
JuMP.register(m, :f, 3, f, autodiff=true)
JuMP.register(m, :f_prime, 3, f_prime, autodiff=true)
JuMP.register(m, :u_crra_prime_inv, 2, u_crra_prime_inv, autodiff=true)

# %% [markdown]
# The auxiliary and equilibrium constraints are all defined on the grid with 10 nodes:

# %%
@NLconstraint(m, EE[i=1:10], sum(Ψ[i, k] * θ[k] for k in 1:10) == 
    u_crra_prime_inv(
    β * u_crra_prime(sum(Ψprime(f(K[i], α, A) + (1-δ)*K[i] - sum(Ψ[i, k] * θ[k] for k in 1:10), k) * θ[k] for k in 1:10), γ) * 
    (f_prime(f(K[i], α, A) + (1-δ)*K[i] - sum(Ψ[i, k] * θ[k] for k in 1:10), α, A) + 1-δ)
    , γ));

# %% [markdown]
# I define auxiliary expressions for the predictions of the equilibrium conditions:

# %%
@NLexpression(m, predictedK[t=2:100], f(dataK[t-1], α, A) + (1-δ)*dataK[t-1] - dataC[t-1])
@NLexpression(m, predictedC[t=1:100], sum(Φ[t, k] * θ[k] for k in 1:10));

# %% [markdown]
# The objective is to minimize the sum of squared errors:

# %%
@NLobjective(m, Min, sum((dataC[t] - predictedC[t])^2 for t in 1:100) +
    sum((dataK[t] - predictedK[t])^2 for t in 2:100))

# %%
solve(m)
# Out:
# This is Ipopt version 3.12.1, running with linear solver mumps.
# NOTE: Other linear solvers might be more efficient (see Ipopt documentation).
#
# Number of nonzeros in equality constraint Jacobian...:      150
# Number of nonzeros in inequality constraint Jacobian.:        0
# Number of nonzeros in Lagrangian Hessian.............:        0
#
# Total number of variables............................:       15
#                      variables with only lower bounds:        2
#                 variables with lower and upper bounds:        3
#                      variables with only upper bounds:        0
# Total number of equality constraints.................:       10
# Total number of inequality constraints...............:        0
#         inequality constraints with only lower bounds:        0
#    inequality constraints with lower and upper bounds:        0
#         inequality constraints with only upper bounds:        0
#
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#    0  1.3838790e+03 9.47e+00 6.17e+01   0.0 0.00e+00    -  0.00e+00 0.00e+00   0
#    1  1.0439571e+03 7.91e+00 5.74e+02   1.0 5.00e+01    -  5.73e-06 1.65e-06F  1
#    2  3.0313196e+02 2.49e+00 3.22e+02  -0.6 1.90e+00    -  1.00e+00 1.00e+00f  1
#    3  1.7359935e+02 1.98e+00 1.38e+02   0.8 2.66e+00    -  9.61e-01 1.75e-01f  2
#    4  7.2671983e+01 1.87e-01 7.01e+01   0.4 7.72e-01    -  9.82e-01 1.00e+00f  1
#    5  3.8667746e+01 8.49e-03 7.99e+02   0.7 1.65e+00    -  5.84e-01 7.47e-01h  1
#    6  1.2445357e+02 2.30e+00 1.22e+06   0.8 1.06e+00    -  1.00e+00 1.00e+00f  1
#    7  8.4404599e+01 1.13e+00 2.98e+05   0.6 1.35e-01    -  1.00e+00 1.00e+00f  1
#    8  6.1969272e+01 8.97e-01 2.83e+04   0.6 3.77e-01    -  5.61e-01 1.00e+00f  1
#    9  2.1850618e+01 4.83e-01 2.37e+03   0.6 2.77e-01    -  1.00e+00 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   10  2.1406630e+01 2.72e-01 6.39e+02   0.4 8.13e-01    -  1.00e+00 6.06e-01h  1
#   11  6.5051403e+00 1.28e+00 4.10e+03   0.7 1.21e+00    -  1.00e+00 3.95e-01f  2
#   12  1.6365847e+01 3.75e-01 5.73e+02   0.1 2.03e-01    -  1.00e+00 1.00e+00h  1
#   13  1.0626914e+01 1.20e-01 1.16e+02  -1.0 9.37e-02    -  1.00e+00 1.00e+00f  1
#   14  7.8111693e+00 2.14e-01 9.38e+01  -0.4 3.60e+00    -  1.00e+00 3.12e-02f  6
#   15  9.4011988e+00 4.38e-02 4.94e+01  -1.8 1.18e-01    -  1.00e+00 5.00e-01h  2
#   16  1.0071898e+01 2.50e-02 3.04e+01  -2.5 8.03e-02    -  1.00e+00 1.00e+00h  1
#   17  1.0612069e+01 4.56e-03 3.96e+00  -3.9 3.63e-02    -  1.00e+00 1.00e+00h  1
#   18  9.2447830e+00 2.92e-03 5.27e+00  -5.5 4.47e-02    -  1.00e+00 1.00e+00f  1
#   19  8.6219833e+00 4.19e-02 2.24e+01  -5.4 2.32e+00    -  1.00e+00 4.25e-02f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   20  7.3473366e+00 8.40e-03 3.93e+00  -3.9 3.24e-02    -  1.00e+00 1.00e+00h  1
#   21  7.1218621e+00 8.12e-05 1.79e+00  -4.9 2.04e-02    -  1.00e+00 1.00e+00h  1
#   22  5.9240949e+00 3.34e-03 5.57e+00  -5.8 1.29e-01    -  1.00e+00 1.00e+00f  1
#   23  5.2411000e+00 1.01e+00 1.28e+01  -6.6 7.07e-01    -  1.00e+00 2.50e-01f  3
#   24  6.1933665e+00 2.03e-01 1.35e+01  -6.7 1.40e-01    -  1.00e+00 1.00e+00h  1
#   25  5.8426762e+00 1.07e+00 1.04e+01  -6.7 1.19e-01    -  1.00e+00 1.00e+00h  1
#   26  6.1142783e+00 9.44e-01 1.64e+01  -6.7 2.06e+00    -  1.54e-01 6.25e-02h  5
#   27  5.2290863e+00 2.19e-01 6.16e+00  -6.7 1.77e-01    -  1.00e+00 1.00e+00h  1
#   28  4.3957779e+00 4.60e-01 1.35e+01  -7.6 1.34e-01    -  7.52e-01 1.00e+00H  1
#   29  3.2766639e+00 2.33e-01 2.60e+01  -7.5 2.67e-01    -  1.00e+00 5.00e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   30  3.2182617e+00 1.00e-01 2.08e+01  -7.9 8.05e-01    -  1.00e+00 4.31e-01h  2
#   31  2.8439120e+00 9.29e-02 9.54e+00  -6.0 8.12e+00    -  1.00e+00 1.90e-02f  2
#   32  1.7929878e+00 1.43e-01 6.98e+00  -5.7 3.27e-01    -  1.00e+00 1.00e+00h  1
#   33  2.0974237e+00 6.76e-02 2.02e+01  -5.0 1.88e+00    -  1.00e+00 2.04e-01H  1
#   34  9.2558308e-01 6.88e-02 1.00e+01  -4.9 3.04e-01    -  1.00e+00 1.00e+00f  1
#   35  6.3758859e-01 3.25e-02 2.28e+00  -4.1 5.50e-02    -  1.00e+00 1.00e+00h  1
#   36  5.9093905e-01 5.73e-03 1.03e+00  -5.0 6.77e-02    -  1.00e+00 1.00e+00h  1
#   37  5.8394956e-01 1.91e-04 1.91e-01  -6.0 8.41e-03    -  1.00e+00 1.00e+00h  1
#   38  5.8346807e-01 5.50e-06 9.44e-02  -7.6 3.74e-03    -  1.00e+00 1.00e+00h  1
#   39  5.8112428e-01 4.99e-04 2.38e-01  -8.6 3.37e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   40  5.7640796e-01 2.23e-03 6.62e-01  -7.8 3.36e+00    -  1.00e+00 3.31e-02h  4
#   41  8.3626075e-01 2.87e-03 7.21e+00  -8.7 1.63e-01    -  1.00e+00 1.00e+00h  1
#   42  5.6729448e-01 3.92e-03 3.14e-01  -8.8 1.23e-01    -  1.00e+00 1.00e+00h  1
#   43  6.6235124e-01 7.30e-04 4.88e+00  -9.2 1.28e-01    -  9.64e-01 1.00e+00H  1
#   44  5.4214842e-01 2.61e-03 3.93e-01  -9.3 2.40e-01    -  1.00e+00 1.00e+00h  1
#   45  5.3620438e-01 2.73e-03 4.41e-01  -9.0 1.93e+00    -  1.00e+00 3.65e-02h  5
#   46  5.5466687e-01 2.77e-03 2.48e+00  -9.5 1.50e+00    -  1.00e+00 5.88e-02h  5
#   47  5.2819787e-01 1.31e-04 4.85e-02  -9.4 8.80e-02    -  1.00e+00 1.00e+00h  1
#   48  5.2052821e-01 1.01e-04 2.50e-01 -10.8 1.56e-01    -  1.00e+00 1.00e+00h  1
#   49  5.1831853e-01 1.03e-03 1.12e+00  -8.8 7.87e+01    -  1.00e+00 2.77e-03f  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   50  5.5433289e-01 3.68e-04 3.29e+00  -8.7 6.17e+00    -  1.00e+00 1.00e+00H  1
#   51  5.5407619e-01 4.17e-04 3.49e+00  -8.8 5.66e+02    -  4.36e-03 1.99e-04f  4
#   52  5.4717644e-01 4.16e-04 4.43e+00  -8.8 1.05e+02    -  4.87e-02 2.59e-03h  7
#   53  4.0948638e-01 2.12e-03 4.07e-01  -8.8 3.47e-01    -  1.00e+00 1.00e+00h  1
#   54  4.1835102e-01 2.33e-03 2.99e-01  -8.9 3.58e-01    -  1.00e+00 1.00e+00h  1
#   55  4.1502844e-01 2.50e-03 6.62e-01  -8.3 4.66e+01    -  1.00e+00 3.90e-02h  5
#   56  4.1227443e-01 4.88e-03 1.22e+00  -6.7 7.21e+03    -  1.00e+00 6.83e-04f  5
#   57  3.9932456e-01 4.86e-03 2.17e-01  -6.8 2.11e+01    -  4.30e-02 1.59e-02h  4
#   58  3.8316018e-01 5.43e-03 4.94e-01  -5.0 2.14e+02    -  1.00e+00 1.07e-02h  2
#   59  6.2128629e-01 9.40e-03 6.36e+00  -4.7 2.10e+00    -  1.00e+00 1.00e+00H  1
# Warning: Cutting back alpha due to evaluation error
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   60  6.6655583e-01 9.26e-03 3.96e+00  -4.8 3.94e+02    -  3.02e-02 1.07e-02h  3
#   61  3.7802766e-01 5.36e-03 7.85e-01  -4.8 3.22e+02    -  3.86e-02 3.37e-02f  1
#   62  3.5196652e-01 2.73e+00 4.50e+00  -6.2 3.78e-01    -  1.00e+00 1.00e+00h  1
#   63  3.1714810e+00 4.75e-01 3.27e+01  -1.6 2.25e+01    -  1.00e+00 1.00e+00h  1
#   64  2.9326392e+00 4.82e-01 3.33e+01  -1.8 5.68e+00    -  3.79e-06 1.63e-06H  1
#   65  2.6153442e+00 3.33e+00 2.85e+01  -1.8 4.12e+00    -  1.75e-01 6.25e-02h  2
#   66  2.0010210e+00 6.49e+00 9.21e+00  -1.8 2.08e+00    -  6.09e-01 1.38e-01h  2
#   67  1.7279065e+00 6.08e+00 4.01e+01  -1.8 4.36e-01    -  5.50e-01 5.00e-01h  2
#   68  1.0446012e+00 2.40e+00 4.11e+00  -1.8 2.15e-01    -  1.00e+00 1.00e+00h  1
#   69  6.2640516e-01 1.03e+00 8.35e-01  -1.8 3.08e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   70  1.7527711e+01 2.14e-01 3.64e+01  -1.8 9.43e-01    -  6.42e-01 1.00e+00h  1
#   71  2.8980686e+00 2.49e-01 1.42e+01  -1.8 4.14e-01    -  1.00e+00 1.00e+00f  1
#   72  3.1931400e+00 1.11e-01 4.67e+01  -1.8 1.05e+00    -  1.00e+00 4.54e-01h  2
#   73  7.3018821e+00 1.20e-01 7.74e+00  -1.8 4.80e-01    -  9.40e-01 1.00e+00H  1
#   74  2.4463431e+00 5.95e-02 5.38e+01  -1.8 4.63e-01    -  5.08e-01 1.00e+00f  1
#   75  8.1508075e-01 1.31e-01 3.50e+01  -1.8 9.48e-02    -  1.00e+00 1.00e+00h  1
#   76  9.3498747e-01 3.60e-02 3.27e+00  -1.8 1.80e-01    -  1.00e+00 1.00e+00H  1
#   77  6.1507764e-01 4.23e-02 2.18e+00  -1.8 1.96e-01    -  1.00e+00 1.00e+00h  1
#   78  6.8584987e-01 7.93e-03 5.26e+00  -1.8 2.35e-01    -  1.00e+00 1.00e+00h  1
#   79  5.6865844e-01 1.15e-01 3.71e+00  -1.8 1.30e+00    -  1.00e+00 5.00e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   80  4.8810716e-01 8.60e-02 1.27e+00  -1.8 4.56e-01    -  1.00e+00 1.00e+00h  1
#   81  5.0066472e-01 6.11e-03 2.26e+00  -1.8 1.01e-01    -  1.00e+00 1.00e+00h  1
#   82  4.4630785e-01 2.52e-02 1.34e+00  -1.8 1.39e-01    -  1.00e+00 1.00e+00h  1
#   83  4.7383335e-01 1.25e-02 3.48e-01  -1.8 6.02e-02    -  1.00e+00 1.00e+00h  1
#   84  4.4174551e-01 3.20e-03 2.07e-01  -1.8 2.25e-01    -  1.00e+00 1.00e+00h  1
#   85  4.4769693e-01 2.09e-03 1.99e+00  -2.5 3.65e-01    -  1.00e+00 1.00e+00H  1
#   86  4.3286774e-01 2.78e-03 7.09e-01  -3.2 8.03e-01    -  1.00e+00 2.17e-01h  2
#   87  4.2572457e-01 7.12e-03 2.96e-01  -3.1 1.38e+01    -  1.40e-01 7.88e-03h  5
#   88  4.0559579e-01 4.44e-03 5.96e-01  -3.1 7.28e-01    -  7.04e-01 1.00e+00h  1
#   89  4.4759033e-01 2.51e-03 5.20e-01  -3.6 4.17e-01    -  9.75e-01 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#   90  3.7814783e-01 2.39e-02 1.11e-01  -4.1 1.13e-01    -  9.94e-01 1.00e+00H  1
#   91  3.7354675e-01 3.15e-02 9.76e-01  -4.2 1.65e+02    -  5.69e-02 5.34e-03h  3
#   92  3.8420510e-01 2.73e-02 7.57e-01  -3.5 1.90e+00    -  1.00e+00 2.50e-01h  3
#   93  3.7894036e-01 3.69e-02 1.11e+00  -3.5 1.01e+01    -  1.08e-01 2.13e-02h  4
#   94  3.7818597e-01 3.65e-02 1.05e+00  -3.5 9.31e+00    -  2.77e-01 1.56e-02h  7
#   95  3.7736877e-01 4.79e-02 9.94e-01  -3.5 1.47e+02    -  1.16e-01 7.14e-03h  4
#   96  3.5709224e-01 5.12e-02 9.32e-02  -3.5 4.45e+00    -  1.00e+00 2.01e-01h  3
#   97  4.0715916e+00 3.35e-02 1.95e+01  -3.1 2.40e+00    -  1.00e+00 7.36e-01H  1
#   98  1.9345794e+00 2.45e-02 9.71e+00  -3.2 1.99e+01    -  1.98e-01 3.36e-01f  1
#   99  1.3061987e+00 4.67e+01 1.44e+02  -3.2 7.93e+00    -  2.07e-01 1.00e+00f  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  100  3.6777308e+00 2.02e+00 2.59e+01  -3.2 1.02e+02    -  3.39e-16 2.24e-15H  1
#  101  2.5823064e+00 7.90e-01 8.49e+00  -3.2 2.75e-01    -  1.87e-02 1.00e+00h  1
#  102  1.0091708e+01 6.53e-01 1.23e+01  -3.2 1.16e+00    -  5.96e-01 1.52e-01h  2
#  103  1.1205233e+00 1.69e-01 4.02e+00  -3.2 1.67e-01    -  1.00e+00 1.00e+00f  1
#  104  5.1303065e+00 1.53e-01 1.39e+01  -3.2 1.65e-01    -  1.00e+00 1.00e+00h  1
#  105  1.7623053e+00 3.19e-01 1.20e+01  -3.2 1.39e-01    -  1.00e+00 1.00e+00f  1
#  106  1.3977764e+00 2.79e-02 3.75e+00  -3.2 7.03e-02    -  1.00e+00 9.49e-01h  1
#  107  1.4360957e+00 2.74e-02 4.65e+00  -3.2 1.76e+00    -  5.66e-02 1.64e-02h  5
#  108  1.4891078e+00 4.41e-03 7.23e+00  -3.2 7.13e-02    -  1.00e+00 1.00e+00h  1
#  109  3.0318946e+00 1.56e-03 9.84e+00  -3.2 1.76e-01    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  110  8.1482310e-01 1.17e-03 6.74e-01  -3.2 1.13e-01    -  1.00e+00 1.00e+00f  1
#  111  7.0545600e-01 1.08e-04 2.98e-01  -3.2 1.91e-02    -  8.03e-01 1.00e+00h  1
#  112  5.1409155e-01 6.09e-03 6.03e+00  -3.2 1.26e-01    -  1.00e+00 1.00e+00f  1
#  113  2.9170560e-01 3.44e-04 2.88e+00  -3.2 2.42e-02    -  1.00e+00 1.00e+00h  1
#  114  1.6480906e-01 1.20e-03 1.04e+00  -3.9 1.26e-01    -  1.00e+00 3.40e-01h  1
#  115  1.9995122e-01 1.22e-03 2.13e+00  -2.0 1.06e+00    -  1.00e+00 6.21e-02f  3
#  116  2.1102122e-01 7.93e-03 1.85e+00  -2.2 8.04e-02    -  1.00e+00 1.00e+00h  1
#  117  1.0102057e-01 6.11e-04 1.94e+00  -2.2 1.35e-01    -  1.00e+00 1.00e+00h  1
#  118  2.6767464e-01 1.13e-03 4.15e+00  -1.4 4.56e+00    -  1.00e+00 6.00e-02f  4
#  119  8.0023033e-02 8.92e-04 3.26e+00  -1.6 3.17e-01    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  120  1.5039715e-01 2.44e-03 4.47e+00  -1.1 2.61e-01    -  1.00e+00 2.50e-01f  3
#  121  1.0580051e-01 2.86e-03 7.08e-01  -1.3 3.13e-01    -  1.00e+00 1.00e+00h  1
#  122  3.7499530e-01 2.43e-02 2.60e+00  -1.3 1.85e+00    -  1.00e+00 1.00e+00h  1
#  123  3.1290604e-01 2.07e-02 4.67e-01  -1.3 5.47e+00    -  1.00e+00 2.50e-01h  3
#  124  4.1286666e-01 8.44e-03 1.71e+00  -2.0 1.35e+00    -  6.33e-01 7.96e-01h  1
#  125  2.1975577e-01 2.55e-02 1.64e+00  -2.0 3.11e+00    -  3.73e-01 1.00e+00f  1
#  126  1.8193907e+00 1.08e-02 1.18e+01  -2.0 7.77e+00    -  6.41e-01 1.71e-01h  1
#  127  5.9235052e-01 3.62e-03 7.49e+00  -2.0 6.18e+00    -  8.99e-01 5.00e-01f  2
#  128  3.5363937e-01 5.75e-03 9.63e-01  -2.0 1.60e+01    -  5.21e-01 2.01e-01f  2
#  129  2.2597193e-01 8.85e-03 6.33e-01  -2.0 5.21e+01    -  9.37e-01 1.02e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  130  2.3794296e-01 1.04e-02 8.95e-01  -2.0 6.41e+00    -  3.26e-01 4.05e-02h  3
#  131  1.9785036e-01 3.76e-03 3.95e+00  -2.0 9.49e-01    -  1.00e+00 1.00e+00h  1
#  132  1.6465597e-01 2.24e-03 2.09e+00  -2.0 9.43e+00    -  1.90e-01 1.25e-01f  4
#  133  5.5621547e-02 3.57e-03 1.19e-01  -2.0 2.63e+00    -  1.00e+00 1.00e+00h  1
#  134  1.3828185e-02 1.22e-02 4.37e-01  -2.6 4.83e+00    -  9.97e-01 5.00e-01h  2
#  135  8.0702191e-03 1.27e-02 5.94e-01  -3.3 2.92e+00    -  1.00e+00 2.35e-01h  3
#  136  2.6277498e-01 1.27e-02 7.53e-01  -1.1 1.18e+01    -  8.42e-01 3.18e-02f  3
#  137  1.4083156e-01 1.25e-02 2.57e+00  -1.4 2.10e+00    -  1.00e+00 1.00e+00h  1
#  138  3.1859505e-01 3.67e-03 2.43e+00  -1.4 7.84e-01    -  1.00e+00 1.00e+00h  1
#  139  6.9088643e-01 3.99e-03 8.35e+00  -1.4 1.54e+00    -  7.89e-01 5.00e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  140  6.2431840e-01 2.56e-03 5.54e+00  -1.4 2.58e-01    -  6.85e-01 1.00e+00F  1
#  141  3.8531448e-01 2.50e-03 1.80e+00  -1.4 1.01e+01    -  1.00e+00 5.30e-02f  4
#  142  1.7307640e+00 2.09e-03 1.18e+01  -1.4 2.04e+00    -  8.25e-01 9.26e-01H  1
#  143  8.4533916e-01 2.22e-03 1.19e+01  -1.4 1.38e+00    -  1.00e+00 2.50e-01f  3
#  144  1.5267893e-01 3.84e-03 1.27e+02  -1.4 7.02e-01    -  3.77e-01 5.00e-01f  2
#  145  3.6701043e-01 8.23e-03 7.67e+01  -1.4 2.03e+00    -  1.00e+00 5.00e-01h  2
#  146  7.5998026e-02 2.60e-03 1.57e+00  -1.4 9.97e-02    -  1.00e+00 1.00e+00h  1
#  147  7.1708750e-02 4.27e-04 1.56e+00  -2.9 6.71e-01    -  9.99e-01 1.00e+00h  1
#  148  6.4129525e-02 1.49e-03 1.96e+00  -3.0 6.82e-01    -  1.00e+00 2.48e-01h  2
#  149  4.7096496e-02 8.61e-04 5.59e+00  -4.1 7.23e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  150  4.3683028e-02 3.74e-04 3.74e+00  -5.1 2.27e-01    -  1.00e+00 1.00e+00h  1
#  151  4.4569623e-02 1.51e-03 4.09e+00  -2.8 3.61e+00    -  1.00e+00 6.87e-02h  4
#  152  2.5917490e-02 1.60e-03 5.85e-01  -2.9 1.53e+00    -  1.00e+00 1.00e+00h  1
#  153  2.4437125e-02 2.10e-03 5.55e-01  -3.3 6.63e+00    -  1.00e+00 8.52e-02h  4
#  154  1.4008183e-01 1.20e-03 1.06e+00  -3.0 1.87e+00    -  8.76e-01 1.00e+00H  1
#  155  3.0533117e-02 6.09e-03 8.54e-01  -3.2 2.46e+00    -  1.00e+00 1.00e+00h  1
#  156  2.5410452e-02 5.91e-03 6.43e-01  -3.2 7.74e-01    -  1.32e-01 6.91e-02h  3
#  157  2.5470333e-02 5.77e-03 4.20e-01  -3.2 4.30e+00    -  3.90e-01 3.12e-02h  6
#  158  2.3356204e-02 5.14e-03 2.26e-01  -3.2 1.34e+00    -  1.00e+00 1.25e-01h  4
#  159  3.4720237e-02 6.79e-04 3.88e-01  -3.4 6.20e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  160  4.0272011e-02 7.82e-04 1.38e+00  -3.6 1.16e+00    -  1.00e+00 3.67e-02h  4
#  161  3.2102355e-02 3.88e-03 4.97e-01  -3.5 1.34e+00    -  1.00e+00 1.00e+00h  1
#  162  2.7045803e-02 7.03e-03 6.96e-01  -3.7 8.14e+01    -  2.33e-01 1.43e-02h  3
#  163  3.1003705e-02 5.59e-03 4.92e-01  -3.7 1.73e+00    -  7.48e-01 2.50e-01h  3
#  164  2.8602990e-02 5.56e-03 2.56e-01  -3.7 6.74e+00    -  4.59e-01 9.75e-03h  5
#  165  7.4547836e-02 2.12e-03 4.58e-01  -3.7 8.78e-01    -  4.63e-01 1.00e+00h  1
#  166  1.6580391e-02 2.16e-03 6.41e-02  -3.7 7.47e-01    -  1.00e+00 1.00e+00h  1
#  167  2.5263632e-02 8.36e-04 1.13e-01  -3.5 1.91e+00    -  1.00e+00 1.18e-01h  3
#  168  2.4565736e-02 8.27e-04 9.33e-02  -3.2 2.36e+00    -  1.00e+00 4.66e-02h  5
#  169  3.2885007e-02 3.85e-03 3.55e-01  -2.4 1.51e+01    -  1.00e+00 6.33e-02h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  170  2.1207901e-01 1.36e-03 3.45e+00  -2.5 3.70e+00    -  7.43e-01 1.00e+00H  1
#  171  2.0100514e-01 2.58e-03 2.32e+00  -2.5 1.73e+00    -  5.23e-01 2.55e-02h  5
#  172  1.9136407e-01 3.39e-03 7.00e-01  -2.5 6.35e+00    -  8.53e-01 5.04e-02h  4
#  173  1.2450369e-01 2.55e-03 1.08e+00  -2.5 8.71e+00    -  9.47e-01 1.97e-01h  3
#  174  9.8211644e-02 1.77e-03 2.00e+00  -2.5 1.04e+00    -  1.00e+00 5.00e-01h  2
#  175  6.0955626e-02 8.92e-04 1.89e-01  -2.5 1.79e+00    -  1.00e+00 1.00e+00H  1
#  176  4.6279167e-02 1.35e-03 6.66e-01  -2.5 1.57e+01    -  3.11e-01 8.11e-02h  3
#  177  5.0031905e-02 1.28e-03 1.10e+00  -2.5 4.18e+00    -  1.00e+00 6.25e-02h  5
#  178  4.8553791e-02 1.22e-03 9.52e-01  -2.5 3.06e+00    -  6.98e-01 1.02e-01h  4
#  179  4.1178474e-02 1.40e-03 6.80e-01  -2.5 3.08e+00    -  1.00e+00 1.38e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  180  3.8595475e-02 7.29e-04 4.81e-01  -2.5 8.55e-01    -  1.00e+00 5.00e-01h  2
#  181  3.1561810e-02 3.78e-04 1.40e-01  -4.0 5.25e-01    -  1.00e+00 1.00e+00h  1
#  182  3.1510411e-02 3.90e-04 1.68e-01  -3.2 8.13e+00    -  1.00e+00 1.56e-02h  7
#  183  3.1560035e-02 3.94e-04 1.27e-01  -3.5 1.68e+01    -  1.00e+00 3.91e-03h  9
#  184  3.3280931e-02 2.10e-04 8.28e-02  -4.6 2.40e-01    -  1.00e+00 1.00e+00h  1
#  185  3.2373932e-02 2.12e-04 1.21e-01  -3.2 6.56e+00    -  1.00e+00 3.30e-02h  5
#  186  3.1726497e-02 3.16e-04 2.36e-01  -3.5 1.07e+01    -  1.00e+00 2.82e-02h  5
#  187  3.2959666e-02 9.65e-05 9.09e-01  -3.7 2.23e-01    -  1.00e+00 1.00e+00H  1
#  188  3.3480736e-02 3.25e-04 4.77e-01  -2.7 4.43e+01    -  1.00e+00 9.64e-03h  6
#  189  2.9209261e-02 4.22e-04 2.31e-01  -2.9 7.56e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  190  2.7225373e-02 1.71e-03 6.04e-02  -4.0 4.52e+00    -  1.00e+00 2.50e-01h  3
#  191  3.0530521e-02 1.64e-03 2.39e-01  -3.8 2.07e+00    -  7.68e-01 1.25e-01h  4
#  192  2.9052261e-02 1.59e-03 2.20e-01  -3.8 2.06e+00    -  1.85e-01 5.06e-02h  4
#  193  2.8700507e-02 1.58e-03 3.08e-01  -3.8 1.90e+00    -  5.00e-01 1.84e-02h  4
#  194  2.1095128e-02 2.49e-04 3.09e-01  -3.8 4.19e-02    -  1.00e+00 1.00e+00h  1
#  195  2.0405755e-02 2.74e-04 5.60e-02  -4.4 5.36e+00    -  1.00e+00 5.10e-02h  5
#  196  1.9756044e-02 2.39e-04 2.19e-01  -3.5 2.31e+00    -  1.00e+00 1.16e-01h  4
#  197  1.9384953e-02 3.24e-04 2.58e-01  -3.8 7.45e+00    -  1.00e+00 2.86e-02h  5
#  198  2.2235487e-02 3.74e-04 4.86e-01  -3.2 1.16e+00    -  1.00e+00 1.06e-01h  4
#  199  9.5820138e-02 7.22e-04 7.64e-01  -3.3 4.82e-01    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  200  1.7564786e-02 7.98e-04 1.57e-01  -3.3 2.32e-01    -  1.00e+00 1.00e+00H  1
#  201  1.6766100e-02 3.40e-04 1.10e-01  -4.2 3.38e-01    -  1.00e+00 1.00e+00h  1
#  202  1.8570985e-02 2.76e-04 1.58e-01  -3.4 1.18e+01    -  1.00e+00 1.02e-02h  7
#  203  1.7528738e-02 3.87e-04 4.32e-01  -4.7 3.01e-01    -  1.00e+00 1.00e+00h  1
#  204  1.6339270e-02 3.03e-04 2.16e-01  -4.8 4.16e+00    -  1.07e-01 3.79e-03h  4
#  205  1.6119920e-02 3.04e-04 1.17e-01  -5.1 7.38e-01    -  1.00e+00 1.64e-02h  4
#  206  2.8543474e-02 2.81e-04 1.41e+00  -6.3 6.48e-01    -  9.76e-01 1.00e+00H  1
# Warning: SOC step rejected due to evaluation error
#  207  2.7926132e-02 2.77e-04 1.32e+00  -5.0 4.93e+00    -  1.16e-01 1.15e-02h  7
#  208  3.1692485e-02 2.20e-04 1.20e+00  -5.0 1.25e+01    -  4.16e-01 1.03e-02h  5
#  209  1.7218285e-02 1.60e-03 6.03e-02  -5.0 6.06e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  210  1.7108477e-02 1.52e-03 1.24e-01  -5.0 9.60e-01    -  1.00e+00 2.50e-01h  3
#  211  1.6752235e-02 1.90e-03 3.59e-01  -5.0 8.71e+01    -  5.72e-02 4.17e-03h  4
# Warning: Cutting back alpha due to evaluation error
#  212  1.6685653e-02 2.39e-03 1.63e-01  -5.0 1.32e+02    -  1.23e-01 2.63e-03h  4
#  213  1.5831267e-02 2.36e-03 5.21e-02  -5.0 2.72e+00    -  1.00e+00 2.16e-02h  6
#  214  2.7979070e-02 9.90e-04 1.42e+00  -4.1 2.99e-01    -  1.00e+00 1.00e+00H  1
#  215  2.8763895e-02 1.93e-03 3.14e-01  -4.2 1.47e+00    -  2.94e-01 1.00e+00H  1
#  216  2.0546157e-02 1.80e-02 4.74e-02  -4.2 4.47e+01    -  6.24e-01 4.47e-02h  2
#  217  2.1333716e-02 1.42e-02 2.29e-01  -4.2 1.04e+00    -  7.27e-01 2.50e-01h  3
#  218  1.8333116e-02 1.39e-02 1.19e-01  -4.2 2.68e+00    -  2.85e-01 1.08e-01h  3
#  219  2.5655045e-02 1.26e-02 7.37e-01  -4.2 8.30e-01    -  1.00e+00 8.05e-02h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  220  2.6234843e-02 9.68e-03 3.42e-01  -4.2 9.23e-01    -  8.85e-01 2.50e-01h  3
# Warning: SOC step rejected due to evaluation error
#  221  2.1971736e-02 9.50e-03 4.47e-01  -4.2 6.79e+00    -  2.02e-01 2.50e-02h  5
#  222  1.9793182e-02 9.53e-03 3.15e-01  -4.2 8.83e+00    -  4.06e-01 3.20e-02h  3
#  223  2.2981611e-02 5.60e-03 6.42e-01  -4.2 9.31e-01    -  1.00e+00 1.00e+00h  1
#  224  2.3288670e-02 5.59e-03 4.27e-01  -4.2 2.23e+01    -  5.17e-01 2.04e-03h  7
#  225  1.7154612e-02 7.82e-04 3.28e-01  -4.2 4.07e-01    -  1.00e+00 1.00e+00h  1
#  226  1.5341202e-02 9.71e-04 2.49e-01  -4.2 8.00e+00    -  2.19e-01 3.17e-02h  3
#  227  1.4532721e-02 4.04e-04 9.71e-02  -5.0 2.69e-01    -  1.00e+00 1.00e+00h  1
#  228  1.4275730e-02 4.63e-04 1.27e-01  -3.0 7.03e+01    -  2.92e-02 1.86e-03h  7
#  229  1.4056361e-02 4.49e-04 5.24e-02  -3.8 1.26e+00    -  1.00e+00 8.75e-02h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  230  1.3407849e-02 4.78e-04 1.39e-02  -4.5 1.27e+00    -  1.00e+00 1.25e-01h  4
#  231  1.4093580e-02 8.61e-06 3.76e-01  -5.9 2.63e-01    -  1.00e+00 1.00e+00H  1
#  232  1.4482453e-02 6.11e-05 3.99e-01  -3.2 6.51e+00    -  3.74e-01 9.96e-03h  5
#  233  1.4082906e-02 6.73e-04 7.78e-02  -3.8 4.24e-01    -  1.00e+00 1.00e+00h  1
#  234  1.4207762e-02 7.20e-04 1.74e-01  -3.8 2.19e+00    -  1.00e+00 8.76e-02h  4
#  235  1.4209070e-02 6.32e-04 2.55e-01  -3.8 1.41e-01    -  1.00e+00 1.25e-01h  4
#  236  1.4418010e-02 5.57e-04 2.28e-01  -3.8 1.68e-01    -  1.00e+00 1.00e+00h  1
#  237  4.0000542e-02 1.37e-05 3.13e-01  -3.8 4.25e-01    -  1.00e+00 1.00e+00H  1
#  238  3.6584045e-02 3.96e-05 2.95e-01  -3.8 1.69e+00    -  1.00e+00 6.25e-02h  5
#  239  3.5600428e-02 5.65e-05 2.88e-01  -3.8 3.40e+01    -  8.91e-02 2.32e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  240  3.4042359e-02 5.83e-05 2.70e-01  -3.8 9.68e-01    -  1.00e+00 3.12e-02h  6
#  241  3.2585656e-02 5.92e-05 2.64e-01  -3.8 9.64e+00    -  6.79e-02 5.28e-03h  8
#  242  3.1685208e-02 1.63e-04 2.97e-01  -3.8 3.59e+01    -  3.12e-01 5.60e-03h  5
#  243  1.9729848e-02 2.40e-03 5.54e-01  -3.8 3.07e-01    -  1.00e+00 5.00e-01h  2
#  244  1.6477424e-02 2.74e-03 4.89e-02  -3.8 5.10e+00    -  8.38e-01 7.34e-02h  3
#  245  1.3652155e-02 1.96e-04 1.70e-02  -3.8 1.99e-01    -  1.00e+00 1.00e+00h  1
#  246  1.3589916e-02 1.72e-04 1.43e-01  -4.4 2.39e-01    -  1.00e+00 6.63e-02h  4
#  247  1.3059929e-02 5.29e-05 1.14e-02  -5.0 1.02e-01    -  1.00e+00 1.00e+00h  1
#  248  1.3874708e-02 8.73e-06 7.77e-02  -6.7 1.56e-01    -  1.00e+00 1.00e+00H  1
#  249  1.3881905e-02 4.18e-06 7.49e-02  -6.2 1.41e+01    -  1.00e+00 2.40e-03h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  250  1.3825757e-02 6.13e-05 7.34e-02  -6.2 8.25e+00    -  1.00e+00 8.59e-03h  4
#  251  1.9967148e-02 1.56e-05 2.86e-01  -5.0 2.20e-01    -  1.00e+00 1.00e+00H  1
#  252  1.8035247e-02 6.72e-05 1.15e-01  -5.0 1.02e-01    -  2.72e-01 1.25e-01h  4
#  253  1.3160144e-02 2.09e-03 2.28e-01  -5.0 6.04e-01    -  1.00e+00 1.00e+00h  1
#  254  1.3247890e-02 2.05e-03 2.31e-01  -5.0 2.22e+00    -  1.77e-01 6.25e-02h  5
#  255  1.3000229e-02 2.05e-03 8.77e-02  -5.0 1.02e+01    -  8.11e-02 8.38e-04h  6
#  256  1.1844486e-02 8.95e-03 1.31e-01  -4.9 1.53e+00    -  1.00e+00 2.62e-01H  1
#  257  4.9398579e-02 6.49e-03 3.80e-01  -5.0 1.30e+00    -  8.33e-01 1.00e+00H  1
#  258  1.4275188e-02 2.15e-02 8.46e-02  -4.7 1.93e+00    -  4.77e-01 1.00e+00h  1
#  259  4.1119805e-02 2.45e-02 3.81e-01  -4.7 9.24e+01    -  1.52e-02 5.42e-03h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  260  3.7950398e-02 1.96e-02 6.69e-01  -4.7 1.99e+00    -  1.00e+00 2.07e-01H  1
#  261  2.9109396e-02 1.29e-02 1.55e-01  -4.7 1.09e+00    -  1.00e+00 5.00e-01f  2
#  262  4.7693141e-02 1.18e-02 9.42e-01  -4.7 2.20e+00    -  1.00e+00 2.50e-01h  3
#  263  1.9220455e+00 4.64e-03 1.38e+01  -4.7 2.65e+00    -  9.07e-01 1.00e+00H  1
#  264  1.5246351e+00 5.45e-03 1.25e+01  -4.7 1.61e+01    -  1.00e+00 1.02e-01f  3
#  265  1.4202270e+00 6.17e-03 1.15e+01  -4.7 1.23e+02    -  2.89e-02 1.20e-02f  5
#  266  9.1363182e-01 8.15e-03 4.47e+00  -4.7 1.99e+04    -  2.49e-04 2.82e-04f  2
#  267  8.9668662e-01 1.68e-02 5.75e+00  -4.7 9.68e+02    -  1.28e-02 1.69e-02h  2
#  268  6.8925235e-01 8.79e-02 2.63e+00  -4.7 1.60e+03    -  6.64e-02 6.13e-03f  1
#  269  5.6965986e-01 8.56e-02 3.24e+00  -4.7 7.07e+02    -  4.36e-02 9.63e-03f  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  270  5.9544101e-01 7.76e-02 3.56e+00  -4.7 1.87e+04    -  1.56e-01 6.78e-04h  2
#  271  4.4267783e-01 1.49e-02 5.30e+00  -4.7 1.75e+02    -  5.62e-02 3.62e-02h  2
#  272  2.6263608e-01 1.77e-02 4.89e+00  -4.7 1.19e+03    -  1.73e-01 2.66e-03f  2
#  273  1.9044924e-01 1.60e-02 3.48e+00  -4.7 2.51e+00    -  1.00e+00 1.07e-01h  1
#  274  1.0570119e-01 3.70e-03 1.35e+00  -4.7 3.17e-01    -  1.00e+00 1.00e+00h  1
#  275  8.7221097e-02 3.09e-03 1.17e+00  -4.7 5.67e-01    -  1.00e+00 1.00e+00h  1
#  276  8.5236854e-02 3.34e-03 7.00e-01  -4.7 2.09e+00    -  1.00e+00 8.11e-02h  4
#  277  7.8008157e-02 3.09e-03 5.97e-01  -4.7 4.75e-01    -  1.00e+00 1.00e+00h  1
#  278  7.8819576e-02 2.98e-03 6.24e-01  -4.7 1.20e+00    -  9.90e-01 3.12e-02h  6
#  279  6.9489707e-02 1.39e-03 3.80e-01  -4.7 5.00e-01    -  1.00e+00 1.00e+00h  1
# Warning: SOC step rejected due to evaluation error
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  280  9.1421099e-02 1.10e-03 7.50e-01  -4.7 1.21e+00    -  3.74e-01 6.25e-02h  5
#  281  6.8524475e-02 1.95e-04 7.13e-02  -4.7 1.17e-01    -  8.13e-01 1.00e+00h  1
#  282  7.0470186e-02 2.48e-04 6.80e-01  -4.7 4.08e-01    -  1.00e+00 2.50e-01h  3
#  283  7.0108833e-02 1.90e-04 7.86e-01  -4.7 1.56e+01    -  7.43e-02 1.51e-02h  7
# Warning: Cutting back alpha due to evaluation error
#  284  6.9801828e-02 1.87e-04 8.05e-01  -4.7 1.04e+02    -  2.08e-01 9.76e-04h  6
#  285  6.5287216e-02 3.75e-04 3.66e-01  -4.7 1.65e+01    -  4.87e-02 2.02e-02h  4
#  286  6.4552209e-02 4.20e-04 6.91e-02  -4.7 1.64e+02    -  3.10e-02 8.21e-04h  5
#  287  6.1518635e-02 1.82e-05 1.37e-01  -4.7 3.49e-02    -  1.00e+00 1.00e+00h  1
#  288  6.1392472e-02 1.32e-04 1.02e-01  -4.7 1.22e+01    -  2.65e-01 1.56e-02h  7
#  289  7.3416158e-02 2.15e-05 1.40e+00  -4.7 2.40e-01    -  1.00e+00 1.00e+00H  1
# Warning: SOC step rejected due to evaluation error
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  290  7.3246641e-02 1.30e-05 1.39e+00  -4.7 3.20e+01    -  1.00e+00 1.85e-03h  7
#  291  7.1530621e-02 1.86e-05 1.40e+00  -4.7 1.03e+01    -  3.03e-02 1.64e-03f  5
# Warning: Cutting back alpha due to evaluation error
#  292  7.1351669e-02 1.87e-05 1.39e+00  -4.7 7.90e+00    -  8.22e-01 9.18e-04h 10
#  293  7.0640285e-02 1.88e-05 1.36e+00  -4.7 1.19e+02    -  3.03e-02 6.17e-05f  9
#  294  7.0143846e-02 1.88e-05 1.34e+00  -4.7 2.08e+00    -  8.74e-01 7.81e-03h  8
#  295  6.2262003e-02 5.84e-04 3.51e-01  -4.7 1.98e+02    -  3.83e-02 2.32e-03f  4
#  296  6.0177406e-02 7.19e-04 3.59e-01  -4.7 7.84e-01    -  1.00e+00 2.50e-01h  3
# Warning: SOC step rejected due to evaluation error
#  297  5.9779440e-02 9.06e-04 3.19e-01  -4.7 2.05e+02    -  6.83e-02 1.05e-03h  5
# Warning: SOC step rejected due to evaluation error
#  298  5.7565153e-02 1.81e-03 1.26e-01  -4.7 1.07e+01    -  1.53e-01 5.04e-02h  5
#  299  5.6267228e-02 1.82e-03 2.53e-02  -4.7 3.68e+01    -  1.11e-02 5.05e-04h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  300  5.8443896e-02 2.34e-04 7.16e-01  -4.7 2.33e-01    -  1.00e+00 1.00e+00h  1
#  301  5.8058549e-02 2.65e-04 6.74e-01  -4.7 8.30e+00    -  2.85e-01 1.13e-02h  6
#  302  6.3935785e-02 1.76e-04 8.54e-01  -4.7 8.32e-01    -  1.00e+00 1.00e+00H  1
#  303  6.1231013e-02 1.61e-04 2.91e-01  -4.7 4.32e-01    -  1.00e+00 2.50e-01h  3
#  304  6.0543022e-02 2.11e-04 1.96e-01  -4.7 2.46e+01    -  1.25e-01 3.77e-03h  6
#  305  5.9709362e-02 2.59e-04 2.49e-01  -4.7 3.33e+02    -  1.36e-02 2.98e-04h  8
#  306  5.9355245e-02 2.60e-04 2.05e-01  -4.7 2.74e+02    -  5.05e-03 6.75e-05h  7
#  307  5.7407609e-02 5.06e-04 2.64e-01  -4.7 3.33e-01    -  1.00e+00 1.00e+00h  1
#  308  5.6425962e-02 5.38e-04 1.79e-01  -4.7 2.77e+00    -  1.69e-01 4.34e-02h  5
#  309  5.6188072e-02 5.43e-04 8.78e-02  -4.7 1.21e+01    -  2.51e-01 5.30e-03h  6
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  310  5.8519055e-02 6.79e-05 4.47e-01  -4.7 4.41e-01    -  1.00e+00 1.00e+00H  1
#  311  5.8501489e-02 6.85e-05 4.71e-01  -4.7 3.54e+00    -  1.97e-01 2.57e-03h  8
#  312  5.8263151e-02 7.75e-05 4.48e-01  -4.7 5.59e+00    -  8.32e-01 2.61e-02h  6
#  313  5.7085193e-02 1.17e-04 3.22e-01  -4.7 7.63e+00    -  2.13e-01 1.56e-02h  7
# Warning: Cutting back alpha due to evaluation error
#  314  5.4351297e-02 9.83e-04 6.51e-02  -4.7 1.17e+02    -  1.40e-01 4.82e-03h  4
#  315  5.4334693e-02 1.02e-03 1.48e-01  -4.7 4.90e+00    -  8.17e-01 3.12e-02h  6
#  316  5.3941829e-02 6.42e-05 1.47e-01  -4.7 3.96e-02    -  1.00e+00 1.00e+00h  1
#  317  5.3632901e-02 8.96e-06 1.03e-02  -4.7 1.81e-02    -  1.00e+00 1.00e+00h  1
#  318  5.3591862e-02 5.54e-05 1.72e-02  -4.7 4.69e+00    -  8.63e-01 3.12e-02h  6
#  319  5.3607146e-02 5.49e-05 3.67e-02  -4.7 3.32e-01    -  1.00e+00 1.47e-02h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  320  5.3588983e-02 5.41e-05 6.32e-02  -4.7 4.59e-01    -  1.00e+00 3.12e-02h  6
#  321  5.3478484e-02 6.22e-05 8.76e-02  -4.7 4.54e+00    -  2.57e-01 1.29e-02h  6
#  322  5.3432586e-02 6.40e-05 1.08e-01  -4.7 8.43e-01    -  1.00e+00 6.25e-02h  5
#  323  5.3284935e-02 8.90e-05 5.66e-02  -4.7 3.75e-02    -  1.00e+00 1.00e+00h  1
# Warning: Cutting back alpha due to evaluation error
#  324  5.3285500e-02 9.09e-05 1.47e-02  -4.7 6.90e+00    -  2.24e-01 4.68e-03h  8
#  325  5.3249904e-02 1.20e-04 7.62e-02  -4.7 2.73e+01    -  1.28e-01 5.02e-03h  7
#  326  5.6101127e-02 7.38e-06 3.94e-01  -4.7 5.70e-01    -  1.00e+00 1.00e+00H  1
#  327  5.6101572e-02 7.30e-06 3.95e-01  -4.7 1.01e+00    -  4.42e-01 1.68e-03h 10
#  328  5.3046220e-02 7.75e-04 3.66e-02  -4.7 5.82e-01    -  1.00e+00 1.00e+00h  1
#  329  5.3109882e-02 6.00e-04 1.34e-02  -4.7 3.36e-01    -  1.00e+00 2.50e-01h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  330  7.2114385e-02 1.72e-06 1.51e+00  -4.7 3.66e-01    -  1.00e+00 1.00e+00H  1
#  331  7.1933466e-02 8.27e-06 1.51e+00  -3.8 1.85e+01    -  1.00e+00 3.91e-03h  7
#  332  6.8357816e-02 9.31e-04 4.19e-01  -3.9 6.74e+00    -  5.14e-01 6.25e-02f  5
#  333  5.6719340e-02 5.45e-03 2.83e-01  -3.9 1.42e+00    -  1.00e+00 1.00e+00h  1
#  334  5.8885584e-02 5.32e-03 3.80e-01  -3.9 3.97e+00    -  8.00e-01 2.25e-02h  3
#  335  5.8180073e-02 5.35e-03 3.71e-01  -3.9 1.30e+01    -  7.24e-01 1.18e-02h  6
#  336  6.9168103e-02 6.56e-04 4.77e-01  -3.9 1.12e+00    -  4.93e-01 1.00e+00H  1
#  337  6.8929392e-02 6.56e-04 7.49e-01  -3.9 3.59e+00    -  9.42e-02 2.84e-03h  7
#  338  5.3774572e-02 3.89e-03 4.14e-02  -3.9 1.22e+00    -  1.00e+00 1.00e+00h  1
#  339  5.3699287e-02 3.75e-03 1.15e-01  -3.9 6.07e-01    -  6.89e-01 5.64e-02h  4
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  340  6.1165662e-02 3.35e-03 3.66e-01  -3.9 1.67e+00    -  1.00e+00 2.50e-01h  3
#  341  5.2491817e-02 5.95e-03 6.53e-01  -3.9 2.28e+00    -  1.00e+00 7.69e-01H  1
#  342  5.3291770e-02 5.60e-03 1.39e-01  -3.9 1.87e+01    -  1.34e-01 4.11e-02h  4
#  343  5.9693186e-02 5.60e-03 2.55e-01  -3.9 1.80e+02    -  3.07e-01 4.37e-03h  4
#  344  6.0678619e-02 5.41e-03 6.92e-01  -3.9 6.48e+00    -  4.31e-01 2.96e-02h  5
#  345  5.6971186e-02 4.69e-03 5.64e-01  -3.9 3.48e+00    -  8.55e-01 1.25e-01h  4
#  346  5.2792096e-02 4.64e-03 4.29e-01  -3.9 4.68e+01    -  9.72e-02 1.14e-02h  5
#  347  5.4852710e-02 1.24e-03 4.43e-02  -3.9 9.77e-01    -  5.27e-01 1.00e+00h  1
#  348  5.4888666e-02 1.23e-03 6.07e-02  -3.9 5.59e+00    -  1.00e+00 1.78e-02h  6
#  349  5.4827165e-02 1.25e-03 3.53e-02  -3.9 1.52e+00    -  4.42e-01 2.46e-02h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  350  5.5283061e-02 1.18e-03 1.19e-01  -3.9 5.85e-01    -  1.00e+00 1.25e-01h  4
#  351  5.3514892e-02 2.07e-04 1.59e-01  -3.9 1.32e-01    -  1.00e+00 1.00e+00h  1
#  352  5.3480698e-02 2.07e-04 1.35e-01  -3.9 1.37e+00    -  1.00e+00 6.25e-02h  5
#  353  5.3522297e-02 2.12e-04 4.38e-02  -3.9 2.14e+00    -  5.25e-01 1.48e-02h  7
#  354  5.3446998e-02 2.13e-04 1.44e-02  -3.9 1.60e+01    -  3.76e-01 1.49e-03h  8
#  355  5.9701441e-02 1.69e-04 7.36e-01  -3.9 9.31e-01    -  1.00e+00 1.00e+00H  1
#  356  5.9708102e-02 1.90e-04 6.25e-01  -3.9 3.67e+01    -  1.56e-01 3.91e-03h  9
#  357  5.8371257e-02 1.95e-04 5.56e-01  -3.9 1.85e+00    -  1.00e+00 6.25e-02h  5
#  358  5.7181604e-02 2.00e-04 4.79e-01  -3.9 6.33e+00    -  1.43e-01 1.15e-02h  7
#  359  5.7036053e-02 2.02e-04 4.77e-01  -3.9 3.31e+00    -  1.00e+00 1.56e-02h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  360  5.6725488e-02 2.03e-04 4.56e-01  -3.9 2.16e+01    -  4.87e-01 9.47e-04h  9
#  361  5.6591969e-02 2.03e-04 4.51e-01  -3.9 7.80e+00    -  2.02e-01 2.58e-03h  9
#  362  5.5992225e-02 2.07e-04 6.08e-02  -3.9 7.44e+00    -  4.46e-01 7.81e-03h  8
#  363  5.4544655e-02 1.13e-03 6.57e-02  -3.9 3.03e+01    -  7.56e-01 2.17e-02h  4
#  364  5.4532031e-02 1.15e-03 1.12e-01  -3.9 8.92e+00    -  2.09e-01 1.11e-02h  6
#  365  5.4018554e-02 1.94e-04 1.31e-01  -3.9 1.85e-01    -  1.00e+00 1.00e+00h  1
#  366  5.3970727e-02 2.15e-04 6.81e-02  -3.9 8.83e+00    -  6.10e-01 1.12e-02h  6
#  367  5.5392340e-02 1.68e-04 5.10e-01  -3.9 3.34e-02    -  1.00e+00 1.00e+00h  1
#  368  5.3870493e-02 1.67e-04 2.41e-02  -3.9 9.53e-02    -  1.00e+00 1.00e+00h  1
#  369  5.8310606e-02 4.30e-05 2.07e-01  -3.9 8.26e-01    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  370  6.1451236e-02 4.31e-05 2.14e-01  -3.9 1.55e-01    -  1.00e+00 6.25e-02h  5
#  371  5.6257520e-02 3.55e-05 1.81e-01  -3.9 1.81e-01    -  1.00e+00 1.00e+00H  1
#  372  5.5267642e-02 9.54e-05 1.46e-01  -3.9 2.33e+01    -  1.74e-01 6.66e-03h  7
#  373  5.4898984e-02 1.43e-04 1.55e-01  -3.9 4.70e+01    -  1.07e-01 2.65e-03h  7
#  374  5.4810915e-02 1.46e-04 1.48e-01  -3.9 3.90e+01    -  5.27e-01 7.55e-04h  9
# Warning: SOC step rejected due to evaluation error
#  375  5.4717694e-02 1.49e-04 1.51e-01  -3.9 1.56e+01    -  3.66e-01 2.18e-03h  9
#  376  5.4135397e-02 2.27e-04 1.16e-01  -3.9 1.35e+01    -  8.64e-01 1.20e-02h  6
#  377  5.4043477e-02 2.68e-04 6.76e-02  -3.9 1.56e+01    -  5.49e-01 9.13e-03h  6
#  378  5.4124679e-02 2.67e-04 9.31e-02  -3.9 3.53e+00    -  5.18e-01 1.38e-03h  9
#  379  5.3801789e-02 6.81e-05 1.88e-02  -3.9 1.52e-01    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  380  5.3785083e-02 6.76e-05 3.03e-02  -3.9 8.28e-01    -  1.00e+00 1.56e-02h  7
#  381  5.3606590e-02 9.38e-05 1.07e-01  -3.9 6.64e-01    -  4.64e-01 2.88e-02h  5
#  382  5.4024490e-02 1.30e-05 2.24e-01  -3.9 1.44e-01    -  1.00e+00 1.00e+00H  1
#  383  5.4004519e-02 2.65e-05 1.28e-01  -3.9 1.93e+01    -  2.32e-01 3.75e-03h  9
#  384  5.4007957e-02 3.98e-05 1.35e-01  -3.9 3.90e+01    -  2.09e-01 2.49e-03h  6
#  385  5.3351717e-02 1.31e-04 9.09e-03  -3.9 2.10e-01    -  1.00e+00 1.00e+00h  1
#  386  5.3356908e-02 1.36e-04 1.54e-02  -3.9 1.15e+01    -  3.95e-01 3.81e-03h  9
#  387  5.3241493e-02 1.49e-04 1.51e-02  -3.9 1.93e+00    -  1.00e+00 3.27e-02h  5
#  388  5.3199519e-02 1.13e-04 8.38e-02  -3.9 1.01e-01    -  1.00e+00 5.00e-01h  2
#  389  5.3534650e-02 1.14e-04 8.91e-02  -3.9 6.82e-01    -  1.00e+00 4.99e-02h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  390  5.3542042e-02 1.14e-04 4.41e-02  -3.9 2.12e-01    -  7.55e-01 6.25e-02h  5
#  391  5.3339074e-02 1.13e-04 3.22e-02  -3.9 1.70e-01    -  1.00e+00 3.12e-02h  6
#  392  5.3103177e-02 4.78e-05 7.03e-02  -3.9 1.42e-01    -  1.00e+00 1.00e+00h  1
#  393  5.3113790e-02 7.81e-05 6.86e-02  -3.9 7.00e+00    -  6.15e-01 1.56e-02h  7
#  394  5.3117093e-02 7.62e-05 5.87e-02  -3.9 1.04e-01    -  1.00e+00 3.12e-02h  6
#  395  5.3095942e-02 7.82e-05 1.91e-02  -3.9 8.18e+00    -  1.00e+00 3.30e-03h  8
#  396  5.3052083e-02 1.19e-06 2.79e-02  -3.9 5.91e-03    -  1.00e+00 1.00e+00h  1
#  397  5.3174567e-02 3.80e-07 9.32e-02  -5.3 8.52e-03    -  1.00e+00 1.00e+00H  1
#  398  5.3138564e-02 2.86e-06 9.60e-02  -5.0 6.48e-01    -  1.00e+00 3.12e-02h  6
#  399  5.3136516e-02 3.64e-06 1.02e-01  -5.1 1.60e+00    -  1.00e+00 1.56e-02h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  400  5.3119165e-02 1.17e-05 1.17e-01  -5.1 2.79e+01    -  1.27e-01 1.95e-03h 10
# Warning: SOC step rejected due to evaluation error
#  401  5.3112050e-02 1.20e-05 1.10e-01  -5.1 1.16e+00    -  1.94e-01 2.08e-03h  9
#  402  5.3023286e-02 1.24e-05 4.29e-03  -5.1 6.43e+00    -  2.05e-01 3.43e-03h  7
#  403  5.3007824e-02 4.25e-07 7.51e-04  -5.1 1.04e-02    -  1.00e+00 1.00e+00h  1
#  404  5.3006011e-02 5.83e-07 3.58e-03  -7.2 8.68e-03    -  1.00e+00 1.00e+00h  1
#  405  6.3707058e-02 1.55e-07 7.93e-02  -8.2 4.24e-02    -  1.00e+00 1.00e+00H  1
#  406  5.5465652e-02 9.87e-04 1.68e-01  -8.4 5.71e-01    -  1.00e+00 1.00e+00f  1
# Warning: Cutting back alpha due to evaluation error
#  407  5.4327042e-02 1.02e-03 1.65e-01  -8.5 5.13e+02    -  5.52e-03 3.01e-04h  6
# Warning: SOC step rejected due to evaluation error
#  408  5.4054978e-02 1.06e-03 1.84e-01  -8.5 2.74e+01    -  1.12e-01 4.47e-03h  6
# Warning: Cutting back alpha due to evaluation error
#  409  5.3702944e-02 1.22e-03 1.24e-02  -8.5 7.26e+03    -  4.87e-04 4.01e-05h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  410  5.3071729e-02 1.38e-05 4.24e-02  -8.5 3.70e-02    -  1.00e+00 1.00e+00h  1
#  411  5.3063932e-02 1.55e-05 1.96e-02  -8.5 2.62e+00    -  6.78e-01 1.56e-02h  7
#  412  5.3012861e-02 3.02e-06 4.68e-03  -8.5 1.20e-02    -  1.00e+00 1.00e+00h  1
#  413  5.3010722e-02 3.45e-07 2.99e-03  -8.5 4.46e-03    -  1.00e+00 1.00e+00h  1
#  414  5.3010230e-02 5.05e-07 1.18e-02  -7.8 9.04e+00    -  1.00e+00 3.17e-04h  9
#  415  5.3055102e-02 1.81e-08 8.14e-03  -7.8 3.73e-02    -  1.00e+00 1.00e+00H  1
#  416  5.3052805e-02 7.73e-07 1.26e-02  -6.1 1.55e+02    -  1.00e+00 9.12e-05h  8
#  417  5.3074976e-02 2.80e-07 2.56e-02  -6.1 1.52e-01    -  1.00e+00 1.00e+00H  1
# Warning: SOC step rejected due to evaluation error
#  418  5.3071426e-02 3.53e-07 3.06e-02  -6.1 1.63e+00    -  4.48e-01 1.95e-03h 10
#  419  5.3057556e-02 6.42e-07 2.67e-02  -6.1 9.24e-01    -  1.00e+00 4.18e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  420  5.3228325e-02 6.98e-09 6.38e-02  -6.1 1.12e-01    -  1.00e+00 1.00e+00H  1
#  421  5.3218810e-02 9.02e-08 6.24e-02  -6.1 3.63e+02    -  6.09e-03 1.36e-05f 11
#  422  5.3211840e-02 1.52e-07 6.14e-02  -6.1 1.32e+00    -  1.00e+00 3.91e-03h  9
#  423  5.3125563e-02 2.57e-05 1.04e-01  -6.1 1.15e+02    -  2.90e-02 9.17e-04f  6
#  424  5.3119344e-02 2.58e-05 1.11e-01  -6.1 8.56e-01    -  1.00e+00 1.56e-02h  7
# Warning: SOC step rejected due to evaluation error
#  425  5.3111486e-02 2.61e-05 1.19e-01  -6.1 1.33e+00    -  1.87e-01 1.77e-03h  9
#  426  5.3281199e-02 9.24e-09 5.87e-02  -6.1 8.98e-02    -  1.00e+00 1.00e+00H  1
# Warning: Cutting back alpha due to evaluation error
#  427  5.3277338e-02 5.87e-08 5.84e-02  -6.1 8.43e+01    -  7.31e-02 5.12e-05h 11
#  428  5.3154832e-02 6.81e-06 5.07e-02  -6.1 3.67e-01    -  1.00e+00 1.25e-01h  4
#  429  5.3153223e-02 1.01e-05 5.08e-02  -6.1 1.75e+01    -  9.17e-02 6.73e-04h  7
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  430  5.3131984e-02 1.24e-05 5.83e-02  -6.1 4.14e-01    -  1.00e+00 1.25e-01h  4
#  431  5.3125725e-02 1.37e-05 5.12e-02  -6.1 2.64e+00    -  6.22e-01 7.76e-03h  7
#  432  5.3110017e-02 2.46e-05 6.61e-02  -6.1 6.32e+01    -  1.10e-02 3.59e-04h  7
#  433  5.3109736e-02 2.47e-05 6.71e-02  -6.1 2.48e+01    -  5.23e-02 6.86e-05h  9
#  434  5.3109726e-02 2.48e-05 6.74e-02  -6.1 6.40e+00    -  1.00e+00 1.25e-04h 10
#  435  5.3109271e-02 2.48e-05 6.60e-02  -6.1 3.25e-01    -  9.26e-01 7.81e-03h  8
#  436  5.3104663e-02 2.46e-05 4.37e-02  -6.1 1.17e-02    -  1.00e+00 7.81e-03h  8
#  437  5.3053510e-02 2.01e-08 6.24e-03  -6.1 1.24e-04    -  1.00e+00 1.00e+00h  1
#  438  5.3028899e-02 2.32e-07 3.26e-03  -8.0 4.92e-04    -  1.00e+00 1.00e+00h  1
#  439  5.3020482e-02 3.63e-08 1.70e-03 -10.1 3.55e-04    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  440  5.3012413e-02 6.30e-08 3.82e-03 -11.0 5.45e-04    -  1.00e+00 1.00e+00h  1
#  441  5.3010185e-02 4.63e-08 4.04e-03 -11.0 4.94e-04    -  1.00e+00 1.00e+00h  1
#  442  5.3009260e-02 3.26e-09 2.53e-04 -11.0 9.46e-05    -  1.00e+00 1.00e+00h  1
#  443  5.3009253e-02 7.16e-11 8.48e-05 -11.0 2.17e-05    -  1.00e+00 1.00e+00h  1
#  444  5.3009219e-02 2.74e-10 2.33e-04 -11.0 4.14e-05    -  1.00e+00 1.00e+00h  1
#  445  5.3008939e-02 3.95e-08 7.24e-04 -11.0 4.31e-04    -  1.00e+00 1.00e+00h  1
#  446  5.3502704e-02 5.70e-09 5.53e-02 -11.0 1.09e-02    -  1.00e+00 1.00e+00H  1
#  447  5.3415302e-02 1.58e-05 1.89e-01 -11.0 2.70e-02    -  1.00e+00 1.00e+00F  1
#  448  6.1762595e-02 3.54e-06 1.01e+00 -11.0 9.50e-03    -  1.00e+00 1.00e+00H  1
#  449  5.3129016e-02 4.62e-05 3.70e-03 -11.0 7.34e-03    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  450  5.3072857e-02 1.35e-05 1.59e-02 -11.0 7.49e-03    -  1.00e+00 1.00e+00h  1
#  451  5.3065962e-02 1.56e-05 5.00e-02 -11.0 2.37e-01    -  1.00e+00 1.56e-02h  7
#  452  5.3063704e-02 1.56e-05 5.53e-02 -11.0 6.54e-02    -  1.00e+00 1.56e-02h  7
#  453  5.3018875e-02 5.73e-07 8.07e-03 -11.0 1.53e-03    -  1.00e+00 1.00e+00h  1
#  454  5.3013327e-02 7.70e-07 6.04e-03 -11.0 1.82e-03    -  1.00e+00 1.00e+00h  1
#  455  5.3010944e-02 1.62e-06 5.43e-03 -11.0 2.62e-03    -  1.00e+00 1.00e+00h  1
#  456  5.3010611e-02 1.64e-06 8.62e-04 -11.0 3.26e-01    -  1.00e+00 7.01e-04h 11
#  457  5.3011373e-02 1.54e-07 4.12e-03 -11.0 1.44e-03    -  1.00e+00 1.00e+00h  1
#  458  5.3011151e-02 6.11e-07 3.67e-03 -11.0 4.51e-02    -  1.00e+00 3.12e-02h  6
#  459  5.3011040e-02 6.13e-07 3.66e-03 -11.0 2.38e-01    -  1.00e+00 1.95e-03h 10
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  460  5.3006680e-02 1.48e-07 1.05e-03 -11.0 7.44e-03    -  1.00e+00 1.00e+00h  1
#  461  5.3005151e-02 2.37e-06 4.89e-03 -11.0 3.13e-02    -  1.00e+00 1.00e+00h  1
#  462  5.3003438e-02 8.88e-08 4.98e-04 -11.0 1.46e-03    -  1.00e+00 1.00e+00h  1
#  463  5.3003428e-02 1.01e-07 7.08e-04 -10.4 3.13e+00    -  1.00e+00 2.02e-04h 11
#  464  5.3003329e-02 2.34e-08 7.20e-05 -10.4 2.75e-03    -  1.00e+00 1.00e+00h  1
#  465  5.3003318e-02 2.73e-08 2.67e-04 -10.2 4.30e+00    -  1.00e+00 2.88e-04h 12
#  466  5.3577667e-02 3.77e-09 2.69e-02 -10.2 3.47e-02    -  1.00e+00 1.00e+00H  1
#  467  5.3576495e-02 1.04e-08 2.66e-02 -10.2 6.03e+00    -  2.50e-01 2.09e-04h 11
#  468  5.3546966e-02 1.82e-08 2.59e-02 -10.2 8.93e-02    -  1.00e+00 7.81e-03h  8
#  469  5.3543553e-02 2.59e-08 2.69e-02 -10.2 2.03e-01    -  9.84e-01 9.77e-04h 11
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  470  5.4552350e-02 4.86e-10 3.75e-02 -10.2 3.56e-02    -  1.00e+00 1.00e+00H  1
#  471  5.4548985e-02 2.45e-09 3.69e-02 -10.2 8.41e-01    -  1.00e+00 9.77e-04h 11
#  472  5.4450887e-02 7.69e-05 1.17e-01 -10.2 1.34e+03    -  3.27e-03 1.43e-04f  6
#  473  5.3463412e-02 6.54e-04 7.26e-02 -10.2 1.39e+01    -  1.00e+00 3.04e-02h  4
#  474  5.3332726e-02 6.96e-04 6.62e-02 -10.2 1.88e+02    -  1.05e-02 7.12e-04h  5
#  475  5.3290360e-02 6.59e-04 1.49e-01 -10.2 7.78e-01    -  1.00e+00 6.25e-02h  5
#  476  5.3121104e-02 6.79e-04 1.13e-01 -10.2 6.85e+00    -  1.57e-01 1.16e-02h  7
#  477  5.3029301e-02 4.13e-06 8.26e-03 -10.2 2.86e-02    -  1.00e+00 1.00e+00h  1
#  478  5.3029025e-02 4.17e-06 9.75e-03 -10.2 3.97e+00    -  5.36e-01 9.77e-04h 11
# Warning: SOC step rejected due to evaluation error
#  479  5.3029023e-02 4.21e-06 7.78e-03 -10.2 6.52e+00    -  4.16e-01 1.08e-03h 10
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  480  5.3012291e-02 3.31e-06 1.78e-02 -10.2 1.06e-02    -  1.00e+00 1.00e+00h  1
#  481  5.3012074e-02 3.34e-06 1.60e-02 -10.2 1.36e+00    -  1.00e+00 3.91e-03h  9
#  482  5.3010784e-02 4.09e-06 1.65e-02 -10.2 8.96e+01    -  8.80e-03 6.78e-05h  8
#  483  5.3003993e-02 3.64e-07 1.73e-03 -10.2 9.90e-03    -  1.00e+00 1.00e+00h  1
#  484  5.3767411e-02 1.29e-07 1.41e-02 -10.2 2.03e-01    -  1.00e+00 1.00e+00H  1
#  485  5.3767489e-02 1.32e-07 1.64e-02 -10.2 1.70e-01    -  1.00e+00 1.50e-03h  9
#  486  5.3012944e-02 4.81e-08 2.19e-03 -10.2 2.58e-01    -  1.00e+00 1.00e+00H  1
#  487  5.3011378e-02 2.23e-07 2.75e-03 -10.2 8.58e+00    -  4.07e-02 1.38e-04h  9
#  488  5.3011143e-02 3.05e-07 2.00e-03 -10.2 1.76e+01    -  1.14e-01 3.05e-04h 11
#  489  5.3003697e-02 8.05e-08 2.06e-03 -10.2 2.07e-02    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  490  5.3003545e-02 1.33e-07 2.13e-04 -10.2 1.04e+02    -  1.59e-02 2.76e-05h 10
#  491  5.3003385e-02 9.26e-08 9.07e-05 -10.2 1.44e-03    -  1.00e+00 1.00e+00h  1
#  492  5.4538935e-02 3.54e-09 1.12e-01 -10.2 7.94e-02    -  1.00e+00 1.00e+00H  1
#  493  5.3295648e-02 4.02e-08 4.79e-02 -10.2 1.43e-01    -  1.00e+00 1.00e+00F  1
#  494  5.3284154e-02 5.40e-08 4.65e-02 -10.2 3.35e+01    -  3.92e-02 4.32e-05h 11
# Warning: SOC step rejected due to evaluation error
#  495  5.3281906e-02 5.64e-08 4.68e-02 -10.2 1.19e+02    -  3.70e-02 2.02e-05h 13
#  496  5.3051137e-02 1.31e-09 1.09e-02 -10.2 3.54e-02    -  1.00e+00 1.00e+00H  1
#  497  5.3026163e-02 3.43e-06 3.08e-02 -10.2 7.99e+01    -  6.61e-02 4.35e-04f  7
#  498  5.3024361e-02 5.07e-06 3.76e-02 -10.2 2.89e+00    -  8.37e-01 7.76e-03h  8
#  499  5.3012587e-02 1.84e-06 1.46e-02 -10.2 2.64e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  500  5.3012578e-02 1.84e-06 1.56e-02 -10.2 3.92e+00    -  1.27e-01 7.86e-05h 12
#  501  5.3640836e-02 1.12e-08 8.44e-02 -10.2 2.18e-02    -  1.00e+00 1.00e+00H  1
#  502  5.3617022e-02 2.93e-08 8.24e-02 -10.2 6.70e-02    -  1.00e+00 7.81e-03h  8
# Warning: Cutting back alpha due to evaluation error
#  503  5.3613053e-02 3.41e-08 8.23e-02 -10.2 5.74e+01    -  4.56e-02 3.75e-05h 12
#  504  5.3609646e-02 3.65e-08 8.22e-02 -10.2 3.46e+02    -  4.66e-03 6.98e-07f 12
#  505  5.3065282e-02 2.93e-07 1.50e-02 -10.2 1.79e-01    -  1.00e+00 1.00e+00H  1
#  506  5.3044928e-02 1.99e-05 3.21e-02 -10.2 3.67e+01    -  1.16e-01 2.14e-03h  9
#  507  5.3044948e-02 1.99e-05 3.10e-02 -10.2 4.89e+00    -  3.63e-01 1.97e-04h 13
#  508  5.3019458e-02 2.86e-06 2.34e-02 -10.2 5.18e-03    -  1.00e+00 1.00e+00h  1
#  509  5.3018468e-02 4.17e-06 2.84e-02 -10.2 2.39e+00    -  7.46e-01 7.81e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  510  5.5243870e-02 2.00e-08 4.74e-02 -10.2 3.37e-01    -  1.00e+00 1.00e+00H  1
#  511  5.5222893e-02 3.03e-08 4.75e-02 -10.2 5.84e-01    -  1.00e+00 3.91e-03h  9
#  512  5.5222142e-02 4.19e-08 4.76e-02 -10.2 2.80e+02    -  8.04e-03 6.74e-06h 12
#  513  5.5216586e-02 4.25e-08 4.70e-02 -10.2 1.15e+00    -  5.59e-01 3.88e-04h 12
#  514  5.5211897e-02 4.40e-08 4.69e-02 -10.2 1.40e+02    -  5.30e-02 5.25e-06f 13
# Warning: Cutting back alpha due to evaluation error
#  515  5.4090688e-02 1.78e-04 2.33e-01 -10.2 2.69e+03    -  2.02e-03 1.09e-04f  5
#  516  5.3708955e-02 2.89e-04 1.57e-01 -10.2 3.54e+02    -  1.77e-03 9.17e-05h  5
#  517  5.3243711e-02 6.94e-05 1.33e-01 -10.2 2.14e-02    -  1.00e+00 1.00e+00h  1
#  518  5.3085952e-02 1.38e-06 7.22e-02 -10.2 1.99e-02    -  1.00e+00 1.00e+00h  1
#  519  5.3085821e-02 1.52e-06 7.16e-02 -10.2 1.37e+00    -  1.00e+00 7.81e-03h  8
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  520  5.3071262e-02 1.45e-05 5.87e-02 -10.2 1.38e+02    -  1.54e-03 5.50e-05h  6
#  521  5.3066914e-02 2.69e-05 1.27e-02 -10.2 4.58e+01    -  4.26e-02 4.25e-04h  6
# Warning: Cutting back alpha due to evaluation error
#  522  5.3064340e-02 2.69e-05 1.93e-02 -10.2 1.30e+01    -  2.98e-01 1.33e-03h  9
#  523  5.3064289e-02 2.78e-05 3.79e-02 -10.2 1.13e-02    -  1.00e+00 1.00e+00h  1
#  524  5.3025228e-02 1.86e-05 6.50e-03 -10.2 1.34e-02    -  1.00e+00 1.00e+00h  1
#  525  5.3023905e-02 1.93e-05 4.48e-03 -10.2 3.81e+00    -  1.00e+00 3.76e-03h  8
#  526  5.3023575e-02 1.93e-05 4.29e-03 -10.2 1.52e+00    -  1.00e+00 3.91e-03h  9
#  527  5.3023301e-02 1.94e-05 1.17e-02 -10.2 9.39e+01    -  4.70e-02 9.04e-05h  9
# Warning: Cutting back alpha due to evaluation error
#  528  5.3022902e-02 1.94e-05 5.92e-03 -10.2 3.44e+02    -  2.07e-01 4.94e-05h  9
#  529  5.3003379e-02 5.42e-07 5.82e-04 -10.2 1.47e-02    -  1.00e+00 1.00e+00h  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  530  5.3003298e-02 7.16e-09 6.15e-05 -10.2 5.77e-04    -  1.00e+00 1.00e+00h  1
#  531  5.3003298e-02 7.87e-09 3.22e-05 -10.9 1.23e-01    -  1.00e+00 1.95e-03h 10
#  532  5.3003320e-02 1.35e-11 7.11e-04 -11.0 7.83e-04    -  1.00e+00 1.00e+00H  1
#  533  5.3003320e-02 2.57e-11 7.24e-04 -11.0 1.04e-01    -  1.00e+00 9.77e-04h 11
#  534  5.3003319e-02 2.53e-10 7.14e-04 -11.0 2.38e+00    -  1.00e+00 1.22e-04h 14
#  535  5.3006660e-02 6.45e-12 5.42e-03 -11.0 1.40e-02    -  1.00e+00 1.00e+00H  1
#  536  5.3006659e-02 1.11e-11 5.43e-03 -11.0 4.02e-01    -  1.00e+00 6.10e-05h 15
#  537  5.3006658e-02 2.25e-11 5.43e-03 -11.0 1.55e+00    -  5.57e-01 1.73e-05h 16
#  538  5.3006650e-02 2.43e-11 5.42e-03 -11.0 8.27e-02    -  1.00e+00 2.44e-04h 13
#  539  5.3003443e-02 4.06e-11 8.58e-04 -11.0 1.81e-02    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  540  5.3003442e-02 4.08e-11 8.51e-04 -11.0 1.26e+01    -  3.45e-01 3.81e-06h 19
#  541  5.3003424e-02 5.17e-09 8.96e-04 -11.0 2.79e+00    -  1.00e+00 4.88e-04h 12
#  542  5.3003343e-02 1.04e-09 3.78e-04 -11.0 5.07e-03    -  1.00e+00 1.00e+00H  1
#  543  5.3003328e-02 1.26e-09 1.92e-04 -11.0 3.24e+00    -  1.49e-01 2.33e-05h 15
#  544  5.3003290e-02 8.28e-11 8.42e-05 -11.0 1.90e-03    -  1.00e+00 1.00e+00H  1
#  545  4.7418094e-02 7.10e-03 7.27e-02 -10.7 1.13e+00    -  1.00e+00 8.07e-01H  1
#  546  1.8734278e-01 4.95e-03 4.13e+00 -10.9 4.87e+02    -  1.73e-07 1.55e-03h  2
#  547  1.0215220e-01 4.30e-03 2.19e+00 -10.9 6.89e-01    -  1.00e+00 2.50e-01h  3
#  548  9.4554718e-02 4.44e-03 1.72e+00 -10.9 5.88e+00    -  7.10e-01 9.78e-02h  4
#  549  8.1712981e-02 4.55e-03 1.43e+00 -10.9 1.51e+02    -  2.26e-01 6.66e-03h  3
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  550  8.1847326e-02 3.37e-03 9.03e-01 -10.9 3.70e+00    -  1.00e+00 2.31e-01H  1
# Warning: SOC step rejected due to evaluation error
#  551  8.5565698e-02 3.13e-03 5.68e-01 -10.9 1.92e-01    -  9.73e-08 2.50e-01h  3
#  552  7.5681461e-02 2.93e-03 2.25e-01 -10.9 3.50e+00    -  9.75e-01 5.59e-02h  3
# Warning: Cutting back alpha due to evaluation error
#  553  6.6007934e-02 2.11e-03 1.69e-01 -10.9 1.26e+01    -  1.96e-01 1.27e-01h  3
# Warning: SOC step rejected due to evaluation error
#  554  6.2720001e-02 2.98e-03 2.72e-01 -10.9 7.45e+03    -  1.34e-04 7.34e-05f  4
#  555  6.6955694e-02 2.81e-03 4.41e-01 -10.9 1.21e+00    -  1.00e+00 1.00e+00H  1
#  556  5.9711171e-02 2.48e-03 5.08e-01 -10.9 2.01e+00    -  1.00e+00 5.00e-01h  2
#  557  5.9324575e-02 2.61e-03 3.18e-01 -10.9 1.09e+02    -  8.42e-02 1.43e-03h  5
#  558  5.7886880e-02 3.09e-03 3.45e-01 -10.9 4.78e+02    -  6.37e-03 6.83e-04h  6
#  559  5.6007541e-02 3.68e-03 5.36e-02 -10.9 1.54e+03    -  1.50e-03 2.81e-04h  5
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  560  5.5994592e-02 3.68e-03 5.22e-02 -10.9 9.18e+01    -  2.89e-02 1.44e-04h  9
#  561  5.5295210e-02 4.75e-04 2.52e-01 -10.9 4.55e-01    -  1.00e+00 1.00e+00h  1
#  562  5.5043761e-02 5.31e-04 4.88e-02 -10.9 4.89e-01    -  1.00e+00 1.00e+00h  1
# Warning: Cutting back alpha due to evaluation error
#  563  5.4794707e-02 5.44e-04 8.35e-02 -10.9 3.94e+01    -  1.37e-01 1.51e-03h  7
#  564  9.3617381e-02 3.43e-04 1.76e-01 -10.9 3.11e+00    -  6.52e-01 1.00e+00H  1
#  565  9.7765561e-02 3.21e-04 1.17e+00 -10.9 8.47e-01    -  9.82e-01 1.25e-01h  4
#  566  8.1233823e-02 1.84e-04 9.96e-01 -10.9 1.49e+02    -  2.42e-01 4.63e-03f  4
# Warning: Cutting back alpha due to evaluation error
#  567  7.7725765e-02 2.63e-04 9.51e-01 -10.9 3.78e+04    -  8.45e-04 1.08e-05f  5
# Warning: Cutting back alpha due to evaluation error
#  568  7.4030775e-02 3.96e-04 8.60e-01 -10.9 3.02e+04    -  1.43e-03 1.26e-05f  5
# Warning: Cutting back alpha due to evaluation error
#  569  7.1953475e-02 4.31e-04 7.74e-01 -10.9 4.39e+04    -  4.37e-03 4.07e-06f  6
# Warning: Cutting back alpha due to evaluation error
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  570  7.1300903e-02 4.39e-04 7.63e-01 -10.9 2.39e+02    -  1.00e+00 3.62e-04h  7
# Warning: Cutting back alpha due to evaluation error
#  571  6.8189868e-02 3.40e-03 7.10e-01 -10.9 2.82e+03    -  1.21e-02 4.83e-04f  3
#  572  6.4358997e-02 3.24e-03 1.12e-01 -10.9 2.38e+00    -  1.00e+00 1.25e-01h  4
#  573  6.0373845e-02 4.35e-03 2.39e-01 -10.9 1.61e+00    -  1.00e+00 5.00e-01h  2
#  574  5.9050171e-02 4.53e-03 3.19e-01 -10.9 2.38e+01    -  1.11e-01 1.02e-02h  4
#  575  1.3274772e+02 3.71e+00 2.24e+02 -10.9 6.99e+00    -  2.26e-01 9.93e-01w  1
#  576  5.0939852e-01 2.83e-02 1.65e+01 -10.9 2.00e+00    -  5.49e-01 1.00e+00w  1
#  577  1.2410797e-01 9.34e-02 5.77e+00 -10.9 4.67e+00    -  4.12e-01 1.00e+00w  1
#  578  5.6265324e-02 4.99e-03 7.17e-02 -10.9 3.33e+00    -  2.26e-01 6.20e-02h  4
#  579  5.9959636e-02 2.82e-03 3.40e-01 -10.9 6.41e-01    -  1.00e+00 5.00e-01h  2
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  580  5.8796734e-02 3.08e-03 3.11e-01 -10.9 2.44e+01    -  1.38e-01 9.40e-03h  7
# Warning: Cutting back alpha due to evaluation error
#  581  5.8676485e-02 3.07e-03 3.10e-01 -10.9 1.04e+01    -  3.48e-01 5.37e-03h  7
#  582  5.8377029e-02 2.97e-03 3.87e-01 -10.9 2.44e+00    -  1.00e+00 4.58e-02h  5
#  583  6.5542575e-02 1.14e-03 1.20e+00 -10.9 5.44e-01    -  1.00e+00 1.00e+00h  1
#  584  6.3106311e-02 1.29e-03 6.62e-01 -10.9 2.62e+00    -  1.00e+00 1.25e-01h  4
# Warning: Cutting back alpha due to evaluation error
#  585  5.3741544e-02 1.48e-03 7.35e-02 -10.9 6.35e+01    -  3.97e-02 4.42e-03h  5
#  586  2.3236713e-01 1.67e-04 4.73e+00 -10.9 9.37e-02    -  1.00e+00 1.00e+00H  1
#  587  5.2004940e-02 1.92e-03 4.22e-02 -10.9 5.30e-01    -  1.00e+00 1.00e+00F  1
#  588  5.6163368e-02 9.99e-04 1.33e-01 -10.9 6.62e-01    -  1.00e+00 1.00e+00h  1
#  589  5.6129760e-02 1.01e-03 1.34e-01 -10.9 5.66e+00    -  1.00e+00 1.85e-02h  6
# Warning: Cutting back alpha due to evaluation error
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  590  5.4292497e-02 1.02e-03 9.45e-02 -10.9 5.54e+00    -  4.11e-01 2.57e-02h  6
#  591  5.4292024e-02 1.02e-03 8.61e-02 -10.9 6.05e+01    -  6.97e-02 8.78e-05h 12
# Warning: Cutting back alpha due to evaluation error
#  592  5.3526252e-02 1.06e-03 5.32e-02 -10.9 4.83e+02    -  1.34e-02 2.86e-04h  6
#  593  5.3158241e-02 9.02e-06 1.05e-02 -10.9 6.19e-02    -  1.00e+00 1.00e+00h  1
#  594  5.3099724e-02 2.26e-05 1.99e-02 -10.9 4.83e+00    -  1.76e-01 9.32e-03h  6
#  595  5.3097781e-02 8.47e-07 1.06e-01 -10.9 6.63e-02    -  1.00e+00 1.00e+00H  1
#  596  5.3097502e-02 9.67e-07 1.04e-01 -10.9 9.61e+00    -  4.50e-01 9.77e-04h 11
#  597  5.3097480e-02 2.80e-06 9.52e-02 -10.9 4.29e+01    -  7.07e-02 6.25e-04h  9
#  598  5.3074861e-02 7.88e-06 8.75e-02 -10.9 5.80e+01    -  2.12e-02 1.65e-04h  7
#  599  5.3100847e-02 3.29e-07 1.09e-01 -10.9 7.18e-02    -  1.00e+00 1.00e+00H  1
# iter    objective    inf_pr   inf_du lg(mu)  ||d||  lg(rg) alpha_du alpha_pr  ls
#  600  5.3103568e-02 4.62e-08 1.25e-02 -10.9 1.05e-01    -  1.00e+00 1.00e+00H  1
#
# Number of Iterations....: 600
#
#                                    (scaled)                 (unscaled)
# Objective...............:   7.3140514100178732e-03    5.3103568132081544e-02
# Dual infeasibility......:   1.2508733967805288e-02    9.0819488306523630e-02
# Constraint violation....:   4.6158778355120944e-08    4.6158778355120944e-08
# Complementarity.........:   1.2737649870871613e-11    9.2481529024250800e-11
# Overall NLP error.......:   1.2508733967805288e-02    9.0819488306523630e-02
#
#
# Number of objective function evaluations             = 2931
# Number of objective gradient evaluations             = 601
# Number of equality constraint evaluations            = 3091
# Number of inequality constraint evaluations          = 0
# Number of equality constraint Jacobian evaluations   = 601
# Number of inequality constraint Jacobian evaluations = 0
# Number of Lagrangian Hessian evaluations             = 0
# Total CPU secs in IPOPT (w/o function evaluations)   =      0.704
# Total CPU secs in NLP function evaluations           =      1.924
#
# EXIT: Maximum Number of Iterations Exceeded.
# WARNING: Not solved to optimality, status: UserLimit
# :UserLimit

# %%
getvalue(β), getvalue(δ), getvalue(α), getvalue(A), getvalue(γ)
# Out:
# (0.9688274996704959, 0.22518951343102028, 0.5060788714318784, 1.1018782500956246, 4.413226538130245)

# %%
plot(nodes(Basis(ChebParams(10, 0.2*k_stst, 2*k_stst)))[1], [0.731039, 0.830067, 0.984055, 1.15697 , 1.32812 , 1.48555 , 1.62093 , 1.72778 , 1.80161 , 1.8393], label="True Policy Fucntion")
plot!(K, Ψ * getvalue(θ), label="Estimated Policy Function")
# Out:
# <img src="data:image/png;base64,..." />

# %% [markdown]
# # Robustness in $\beta$
# Varying the initial value for $\beta$ uncovers severe robustness issues:

# %%
error = zeros(50)
initial_β = linspace(0.95-0.2, 0.95+0.2, 50)

for test in 1:50
    m = Model(solver=IpoptSolver(print_level=0, max_iter=600));
    
    @variable(m, 0 <= β <= 1, start = initial_β[test])
    @variable(m, 0 <= δ <= 1, start = 0.05) #rand(Normal(0.05, 0.1)))
    @variable(m, 0 <= α <= 1, start = 0.3) #rand(Normal(0.3, 0.1)))
    @variable(m, A >= 0, start = 1) #rand(Normal(1., 0.1)))
    @variable(m, γ >= 0, start = 2) #rand(Normal(2., 0.1)));
    @variable(m, θ[1:10], start = 0)
    
    initial_θ = Ψ \ (f.(K, getvalue(α), getvalue(A)) + (1-getvalue(δ))*K - 0.1)

    for i in 1:10
        setvalue(θ[i], initial_θ[i])
    end
    
    @variable(m, modelC[i=1:10], start = 1)
    @variable(m, modelCprime[i=1:10], start = 1)
    @variable(m, modelKprime[i=1:10], start = 1);
        JuMP.register(m, :Ψprime, 2, Ψprime, autodiff=true)
    JuMP.register(m, :u_crra_prime, 2, u_crra_prime, autodiff=true)
    JuMP.register(m, :f, 3, f, autodiff=true)
    JuMP.register(m, :f_prime, 3, f_prime, autodiff=true)
    JuMP.register(m, :u_crra_prime_inv, 2, u_crra_prime_inv, autodiff=true)
        @NLconstraint(m, cons_today[i=1:10], modelC[i] == sum(Ψ[i, k] * θ[k] for k in 1:10))
    @NLconstraint(m, capi_tomor[i=1:10], modelKprime[i] == f(K[i], α, A) + (1-δ)*K[i] - modelC[i]) 
    @NLconstraint(m, cons_tomor[i=1:10], modelCprime[i] == sum(Ψprime(modelKprime[i], k) * θ[k] for k in 1:10))

    @NLconstraint(m, EE[i=1:10], modelC[i] == u_crra_prime_inv(
    β * u_crra_prime(modelCprime[i], γ) * (f_prime(modelKprime[i], α, A) + 1-δ), γ));
    @NLexpression(m, predictedK[t=2:100], f(dataK[t-1], α, A) + (1-δ)*dataK[t-1] - dataC[t-1])
    @NLexpression(m, predictedC[t=1:100], sum(Φ[t, k] * θ[k] for k in 1:10));
    @NLobjective(m, Min, sum((dataC[t] - predictedC[t])^2 for t in 1:100) +
    sum((dataK[t] - predictedK[t])^2 for t in 2:100))
    solve(m);
    error[test] = maximum(abs.([getvalue(β), getvalue(δ), getvalue(α), getvalue(A), getvalue(γ)] - [0.95, 0.05, 0.3, 1, 2]))
end

plot(initial_β, error, ylim=[-0.05,0.05])
# Out:
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# WARNING: Not solved to optimality, status: UserLimit
# <img src="data:image/png;base64,..." />

# %% [markdown]
# The correct solution is not robustly found!
